# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random
from collections import deque

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import yfinance as yf



# https://www.thepythoncode.com/article/stock-price-prediction-in-python-using-tensorflow-2-and-keras

#try changing around the optimizer

# Reproducability
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %%
#units = neurons
def load_data(ticker, period, interval, n_steps=50, scale=True, shuffle=True, lookup_step=1, test_size=.2,
              feature_columns=['Close', 'Volume', 'Open', 'High', 'Low']):
    '''
    :param ticker: Ticker you want to load, dtype: str
    :param period: Time period you want data from, dtype: str(options in program)
    :param interval: Interval for data, dtype:str
    :param n_steps: Past sequence len used to predict, default = 50, dtype: int
    :param scale: Whether to scale data b/w 0 and 1, default = True, dtype: Bool
    :param shuffle: Whether to shuffle data, default = True, dtyper: Bool
    :param lookup_step: Future lookup step to predict, default = 1(next day), dtype:int
    :param test_size: ratio for test data, default is .2 (20% test data), dtype: float
    :param feature_columns: list of features fed into the model, default is OHLCV, dtype: list
    :return:
    '''
    df = yf.download(tickers=ticker, period=period, interval=interval,
                     group_by='ticker',
                     # adjust all OHLC automatically
                     auto_adjust=True, prepost=True, threads=True, proxy=None)

    result = {}
    result['df'] = df.copy()

    for col in feature_columns:
        assert col in df.columns, f"'{col}' does not exist in the dataframe."
    if scale:
        column_scaler = {}
        # scale the data (prices) from 0 to 1
        for column in feature_columns:
            scaler = preprocessing.MinMaxScaler()
            df[column] = scaler.fit_transform(np.expand_dims(df[column].values, axis=1))
            column_scaler[column] = scaler
        # add the MinMaxScaler instances to the result returned
        result["column_scaler"] = column_scaler
    # add the target column (label) by shifting by `lookup_step`
    df['future'] = df['Close'].shift(-lookup_step)
    # last `lookup_step` columns contains NaN in future column
    # get them before droping NaNs
    last_sequence = np.array(df[feature_columns].tail(lookup_step))
    # drop NaNs
    df.dropna(inplace=True)
    sequence_data = []
    sequences = deque(maxlen=n_steps)
    for entry, target in zip(df[feature_columns].values, df['future'].values):
        sequences.append(entry)
        if len(sequences) == n_steps:
            sequence_data.append([np.array(sequences), target])
    # get the last sequence by appending the last `n_step` sequence with `lookup_step` sequence
    # for instance, if n_steps=50 and lookup_step=10, last_sequence should be of 60 (that is 50+10) length
    # this last_sequence will be used to predict future stock prices not available in the dataset
    last_sequence = list(sequences) + list(last_sequence)
    last_sequence = np.array(last_sequence)
    # add to result
    result['last_sequence'] = last_sequence
    # construct the X's and y's
    X, y = [], []
    for seq, target in sequence_data:
        X.append(seq)
        y.append(target)
    # convert to numpy arrays
    X = np.array(X)
    y = np.array(y)
    # reshape X to fit the neural network
    X = X.reshape((X.shape[0], X.shape[2], X.shape[1]))
    # split the dataset
    result["X_train"], result["X_test"], result["y_train"], result["y_test"] = train_test_split(X, y,
                                                                               test_size=test_size, shuffle=shuffle)
    # return the result
    return result

def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="adam", bidirectional=False):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation="linear"))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
N_STEPS = 70
# valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
PERIOD = '1y'
# valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
INTERVAL = '1d'
# Lookup step, 1 is the next day
LOOKUP_STEP = 1
# test ratio size, 0.2 is 20%
TEST_SIZE = 0.2
# features to use
FEATURE_COLUMNS = ["Close", "Volume", "Open", "High", "Low"]
# date now
date_now = time.strftime("%Y-%m-%d")

# > model parameters <
N_LAYERS = 3
#Type of model
CELL = LSTM
# Number of neurons
UNITS = 256
# Dropout rate
DROPOUT = 0.4
# whether to use bidirectional RNNs
BIDIRECTIONAL = False

# > training parameters <
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 400
ticker = "SPY"

#save model
model_name = f"{date_now}_{ticker}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-seq-{N_STEPS}-step-{LOOKUP_STEP}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

# folders that store results
if not os.path.isdir("results"):
    os.mkdir("results")
if not os.path.isdir("logs"):
    os.mkdir("logs")
if not os.path.isdir("data"):
    os.mkdir("data")

data = load_data(ticker, PERIOD, INTERVAL, N_STEPS, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE, feature_columns=FEATURE_COLUMNS)
# save the dataframe
data["df"].to_csv()
# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))
history = model.fit(data["X_train"], data["y_train"],
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(data["X_test"], data["y_test"]),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)
model.save(os.path.join("results", model_name) + ".h5")

# >> Testing the Model <<

data = load_data(ticker, PERIOD, INTERVAL, N_STEPS, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE,
                feature_columns=FEATURE_COLUMNS, shuffle=False)
# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
model_path = os.path.join("results", model_name) + ".h5"
model.load_weights(model_path)

# evaluate the model
mse, mae = model.evaluate(data["X_test"], data["y_test"], verbose=0)
# calculate the mean absolute error (inverse scaling)
mean_absolute_error = data["column_scaler"]["Close"].inverse_transform([[mae]])[0][0]
print("Mean Absolute Error:", mean_absolute_error)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/400
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0441 - mean_absolute_error: 0.2467
# Epoch 1: val_loss improved from inf to 0.02040, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 6s 546ms/step - loss: 0.0446 - mean_absolute_error: 0.2453 - val_loss: 0.0204 - val_mean_absolute_error: 0.1622
# Epoch 2/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0178 - mean_absolute_error: 0.1584
# Epoch 2: val_loss improved from 0.02040 to 0.01648, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0178 - mean_absolute_error: 0.1584 - val_loss: 0.0165 - val_mean_absolute_error: 0.1515
# Epoch 3/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0227 - mean_absolute_error: 0.1715
# Epoch 3: val_loss improved from 0.01648 to 0.01022, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0227 - mean_absolute_error: 0.1715 - val_loss: 0.0102 - val_mean_absolute_error: 0.1226
# Epoch 4/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0154 - mean_absolute_error: 0.1430
# Epoch 4: val_loss did not improve from 0.01022
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0154 - mean_absolute_error: 0.1430 - val_loss: 0.0172 - val_mean_absolute_error: 0.1454
# Epoch 5/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0165 - mean_absolute_error: 0.1481
# Epoch 5: val_loss improved from 0.01022 to 0.00878, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0165 - mean_absolute_error: 0.1481 - val_loss: 0.0088 - val_mean_absolute_error: 0.1142
# Epoch 6/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0149 - mean_absolute_error: 0.1385
# Epoch 6: val_loss did not improve from 0.00878
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0149 - mean_absolute_error: 0.1385 - val_loss: 0.0091 - val_mean_absolute_error: 0.1131
# Epoch 7/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0142 - mean_absolute_error: 0.1361
# Epoch 7: val_loss did not improve from 0.00878
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0142 - mean_absolute_error: 0.1361 - val_loss: 0.0090 - val_mean_absolute_error: 0.1155
# Epoch 8/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0117 - mean_absolute_error: 0.1257
# Epoch 8: val_loss did not improve from 0.00878
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0117 - mean_absolute_error: 0.1257 - val_loss: 0.0128 - val_mean_absolute_error: 0.1250
# Epoch 9/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0127 - mean_absolute_error: 0.1305
# Epoch 9: val_loss improved from 0.00878 to 0.00874, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0127 - mean_absolute_error: 0.1305 - val_loss: 0.0087 - val_mean_absolute_error: 0.1137
# Epoch 10/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0120 - mean_absolute_error: 0.1258
# Epoch 10: val_loss improved from 0.00874 to 0.00800, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0120 - mean_absolute_error: 0.1258 - val_loss: 0.0080 - val_mean_absolute_error: 0.1072
# Epoch 11/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0120 - mean_absolute_error: 0.1247
# Epoch 11: val_loss did not improve from 0.00800
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0120 - mean_absolute_error: 0.1247 - val_loss: 0.0081 - val_mean_absolute_error: 0.1095
# Epoch 12/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0108 - mean_absolute_error: 0.1187
# Epoch 12: val_loss did not improve from 0.00800
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0108 - mean_absolute_error: 0.1187 - val_loss: 0.0095 - val_mean_absolute_error: 0.1138
# Epoch 13/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0105 - mean_absolute_error: 0.1220
# Epoch 13: val_loss improved from 0.00800 to 0.00729, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0105 - mean_absolute_error: 0.1220 - val_loss: 0.0073 - val_mean_absolute_error: 0.1033
# Epoch 14/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0098 - mean_absolute_error: 0.1129
# Epoch 14: val_loss did not improve from 0.00729
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0098 - mean_absolute_error: 0.1129 - val_loss: 0.0074 - val_mean_absolute_error: 0.1031
# Epoch 15/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0095 - mean_absolute_error: 0.1149
# Epoch 15: val_loss improved from 0.00729 to 0.00700, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0095 - mean_absolute_error: 0.1149 - val_loss: 0.0070 - val_mean_absolute_error: 0.1005
# Epoch 16/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0087 - mean_absolute_error: 0.1055
# Epoch 16: val_loss did not improve from 0.00700
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0087 - mean_absolute_error: 0.1055 - val_loss: 0.0071 - val_mean_absolute_error: 0.1004
# Epoch 17/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0085 - mean_absolute_error: 0.1070
# Epoch 17: val_loss improved from 0.00700 to 0.00665, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0085 - mean_absolute_error: 0.1070 - val_loss: 0.0066 - val_mean_absolute_error: 0.0968
# Epoch 18/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0094 - mean_absolute_error: 0.1100
# Epoch 18: val_loss improved from 0.00665 to 0.00642, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0094 - mean_absolute_error: 0.1100 - val_loss: 0.0064 - val_mean_absolute_error: 0.0965
# Epoch 19/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0083 - mean_absolute_error: 0.1015
# Epoch 19: val_loss improved from 0.00642 to 0.00624, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0083 - mean_absolute_error: 0.1015 - val_loss: 0.0062 - val_mean_absolute_error: 0.0965
# Epoch 20/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0095 - mean_absolute_error: 0.1111
# Epoch 20: val_loss improved from 0.00624 to 0.00607, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0095 - mean_absolute_error: 0.1111 - val_loss: 0.0061 - val_mean_absolute_error: 0.0963
# Epoch 21/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0091 - mean_absolute_error: 0.1101
# Epoch 21: val_loss did not improve from 0.00607
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0091 - mean_absolute_error: 0.1101 - val_loss: 0.0113 - val_mean_absolute_error: 0.1253
# Epoch 22/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0090 - mean_absolute_error: 0.1074
# Epoch 22: val_loss did not improve from 0.00607
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0090 - mean_absolute_error: 0.1074 - val_loss: 0.0066 - val_mean_absolute_error: 0.0973
# Epoch 23/400
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0091 - mean_absolute_error: 0.1100
# Epoch 23: val_loss improved from 0.00607 to 0.00604, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0088 - mean_absolute_error: 0.1080 - val_loss: 0.0060 - val_mean_absolute_error: 0.0973
# Epoch 24/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0075 - mean_absolute_error: 0.0976
# Epoch 24: val_loss did not improve from 0.00604
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0075 - mean_absolute_error: 0.0976 - val_loss: 0.0093 - val_mean_absolute_error: 0.1142
# Epoch 25/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0078 - mean_absolute_error: 0.1041
# Epoch 25: val_loss did not improve from 0.00604
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0078 - mean_absolute_error: 0.1041 - val_loss: 0.0063 - val_mean_absolute_error: 0.0959
# Epoch 26/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0070 - mean_absolute_error: 0.1012
# Epoch 26: val_loss did not improve from 0.00604
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0070 - mean_absolute_error: 0.1012 - val_loss: 0.0078 - val_mean_absolute_error: 0.1049
# Epoch 27/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0065 - mean_absolute_error: 0.0933
# Epoch 27: val_loss did not improve from 0.00604
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0065 - mean_absolute_error: 0.0933 - val_loss: 0.0066 - val_mean_absolute_error: 0.0957
# Epoch 28/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0075 - mean_absolute_error: 0.1007
# Epoch 28: val_loss did not improve from 0.00604
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0075 - mean_absolute_error: 0.1007 - val_loss: 0.0070 - val_mean_absolute_error: 0.0969
# Epoch 29/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0072 - mean_absolute_error: 0.1006
# Epoch 29: val_loss did not improve from 0.00604
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0072 - mean_absolute_error: 0.1006 - val_loss: 0.0076 - val_mean_absolute_error: 0.1039
# Epoch 30/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0075 - mean_absolute_error: 0.1005
# Epoch 30: val_loss did not improve from 0.00604
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0075 - mean_absolute_error: 0.1005 - val_loss: 0.0080 - val_mean_absolute_error: 0.1040
# Epoch 31/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0089 - mean_absolute_error: 0.1066
# Epoch 31: val_loss did not improve from 0.00604
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0089 - mean_absolute_error: 0.1066 - val_loss: 0.0063 - val_mean_absolute_error: 0.0951
# Epoch 32/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0069 - mean_absolute_error: 0.0959
# Epoch 32: val_loss did not improve from 0.00604
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0069 - mean_absolute_error: 0.0959 - val_loss: 0.0066 - val_mean_absolute_error: 0.0973
# Epoch 33/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0072 - mean_absolute_error: 0.1010
# Epoch 33: val_loss improved from 0.00604 to 0.00598, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0072 - mean_absolute_error: 0.1010 - val_loss: 0.0060 - val_mean_absolute_error: 0.0935
# Epoch 34/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0069 - mean_absolute_error: 0.0952
# Epoch 34: val_loss did not improve from 0.00598
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0069 - mean_absolute_error: 0.0952 - val_loss: 0.0067 - val_mean_absolute_error: 0.0973
# Epoch 35/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0068 - mean_absolute_error: 0.0959
# Epoch 35: val_loss did not improve from 0.00598
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0068 - mean_absolute_error: 0.0959 - val_loss: 0.0062 - val_mean_absolute_error: 0.0923
# Epoch 36/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0066 - mean_absolute_error: 0.0962
# Epoch 36: val_loss did not improve from 0.00598
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0066 - mean_absolute_error: 0.0962 - val_loss: 0.0062 - val_mean_absolute_error: 0.0920
# Epoch 37/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0064 - mean_absolute_error: 0.0914
# Epoch 37: val_loss did not improve from 0.00598
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0064 - mean_absolute_error: 0.0914 - val_loss: 0.0074 - val_mean_absolute_error: 0.1021
# Epoch 38/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0064 - mean_absolute_error: 0.0940
# Epoch 38: val_loss did not improve from 0.00598
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0064 - mean_absolute_error: 0.0940 - val_loss: 0.0062 - val_mean_absolute_error: 0.0915
# Epoch 39/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0070 - mean_absolute_error: 0.0961
# Epoch 39: val_loss did not improve from 0.00598
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0070 - mean_absolute_error: 0.0961 - val_loss: 0.0069 - val_mean_absolute_error: 0.0981
# Epoch 40/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0062 - mean_absolute_error: 0.0915
# Epoch 40: val_loss did not improve from 0.00598
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0062 - mean_absolute_error: 0.0915 - val_loss: 0.0066 - val_mean_absolute_error: 0.0957
# Epoch 41/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0064 - mean_absolute_error: 0.0944
# Epoch 41: val_loss improved from 0.00598 to 0.00595, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0064 - mean_absolute_error: 0.0944 - val_loss: 0.0060 - val_mean_absolute_error: 0.0919
# Epoch 42/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0072 - mean_absolute_error: 0.0969
# Epoch 42: val_loss did not improve from 0.00595
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0072 - mean_absolute_error: 0.0969 - val_loss: 0.0064 - val_mean_absolute_error: 0.0947
# Epoch 43/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0080 - mean_absolute_error: 0.1054
# Epoch 43: val_loss improved from 0.00595 to 0.00583, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0080 - mean_absolute_error: 0.1054 - val_loss: 0.0058 - val_mean_absolute_error: 0.0912
# Epoch 44/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0067 - mean_absolute_error: 0.0934
# Epoch 44: val_loss improved from 0.00583 to 0.00573, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0067 - mean_absolute_error: 0.0934 - val_loss: 0.0057 - val_mean_absolute_error: 0.0911
# Epoch 45/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0069 - mean_absolute_error: 0.0977
# Epoch 45: val_loss did not improve from 0.00573
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0069 - mean_absolute_error: 0.0977 - val_loss: 0.0080 - val_mean_absolute_error: 0.1041
# Epoch 46/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0060 - mean_absolute_error: 0.0924
# Epoch 46: val_loss did not improve from 0.00573
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0060 - mean_absolute_error: 0.0924 - val_loss: 0.0061 - val_mean_absolute_error: 0.0928
# Epoch 47/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0068 - mean_absolute_error: 0.0927
# Epoch 47: val_loss did not improve from 0.00573
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0068 - mean_absolute_error: 0.0927 - val_loss: 0.0066 - val_mean_absolute_error: 0.0949
# Epoch 48/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0062 - mean_absolute_error: 0.0933
# Epoch 48: val_loss did not improve from 0.00573
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0062 - mean_absolute_error: 0.0933 - val_loss: 0.0066 - val_mean_absolute_error: 0.0957
# Epoch 49/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0063 - mean_absolute_error: 0.0966
# Epoch 49: val_loss did not improve from 0.00573
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0063 - mean_absolute_error: 0.0966 - val_loss: 0.0060 - val_mean_absolute_error: 0.0904
# Epoch 50/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0059 - mean_absolute_error: 0.0900
# Epoch 50: val_loss did not improve from 0.00573
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0059 - mean_absolute_error: 0.0900 - val_loss: 0.0060 - val_mean_absolute_error: 0.0903
# Epoch 51/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0062 - mean_absolute_error: 0.0937
# Epoch 51: val_loss did not improve from 0.00573
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0062 - mean_absolute_error: 0.0937 - val_loss: 0.0062 - val_mean_absolute_error: 0.0920
# Epoch 52/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0063 - mean_absolute_error: 0.0926
# Epoch 52: val_loss did not improve from 0.00573
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0063 - mean_absolute_error: 0.0926 - val_loss: 0.0091 - val_mean_absolute_error: 0.1125
# Epoch 53/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0083 - mean_absolute_error: 0.1065
# Epoch 53: val_loss did not improve from 0.00573
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0083 - mean_absolute_error: 0.1065 - val_loss: 0.0061 - val_mean_absolute_error: 0.0914
# Epoch 54/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0087 - mean_absolute_error: 0.1039
# Epoch 54: val_loss improved from 0.00573 to 0.00540, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0087 - mean_absolute_error: 0.1039 - val_loss: 0.0054 - val_mean_absolute_error: 0.0882
# Epoch 55/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0067 - mean_absolute_error: 0.0954
# Epoch 55: val_loss did not improve from 0.00540
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0067 - mean_absolute_error: 0.0954 - val_loss: 0.0082 - val_mean_absolute_error: 0.1057
# Epoch 56/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0066 - mean_absolute_error: 0.0947
# Epoch 56: val_loss did not improve from 0.00540
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0066 - mean_absolute_error: 0.0947 - val_loss: 0.0058 - val_mean_absolute_error: 0.0890
# Epoch 57/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0064 - mean_absolute_error: 0.0919
# Epoch 57: val_loss did not improve from 0.00540
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0064 - mean_absolute_error: 0.0919 - val_loss: 0.0063 - val_mean_absolute_error: 0.0934
# Epoch 58/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0059 - mean_absolute_error: 0.0916
# Epoch 58: val_loss did not improve from 0.00540
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0059 - mean_absolute_error: 0.0916 - val_loss: 0.0065 - val_mean_absolute_error: 0.0950
# Epoch 59/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0055 - mean_absolute_error: 0.0871
# Epoch 59: val_loss did not improve from 0.00540
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0055 - mean_absolute_error: 0.0871 - val_loss: 0.0059 - val_mean_absolute_error: 0.0886
# Epoch 60/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0052 - mean_absolute_error: 0.0837
# Epoch 60: val_loss did not improve from 0.00540
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0052 - mean_absolute_error: 0.0837 - val_loss: 0.0061 - val_mean_absolute_error: 0.0912
# Epoch 61/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0050 - mean_absolute_error: 0.0824
# Epoch 61: val_loss improved from 0.00540 to 0.00525, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0050 - mean_absolute_error: 0.0824 - val_loss: 0.0053 - val_mean_absolute_error: 0.0850
# Epoch 62/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0054 - mean_absolute_error: 0.0867
# Epoch 62: val_loss did not improve from 0.00525
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0054 - mean_absolute_error: 0.0867 - val_loss: 0.0053 - val_mean_absolute_error: 0.0844
# Epoch 63/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0053 - mean_absolute_error: 0.0865
# Epoch 63: val_loss did not improve from 0.00525
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0053 - mean_absolute_error: 0.0865 - val_loss: 0.0054 - val_mean_absolute_error: 0.0848
# Epoch 64/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0054 - mean_absolute_error: 0.0850
# Epoch 64: val_loss did not improve from 0.00525
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0054 - mean_absolute_error: 0.0850 - val_loss: 0.0055 - val_mean_absolute_error: 0.0870
# Epoch 65/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0055 - mean_absolute_error: 0.0845
# Epoch 65: val_loss did not improve from 0.00525
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0055 - mean_absolute_error: 0.0845 - val_loss: 0.0068 - val_mean_absolute_error: 0.0978
# Epoch 66/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0057 - mean_absolute_error: 0.0897
# Epoch 66: val_loss did not improve from 0.00525
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0057 - mean_absolute_error: 0.0897 - val_loss: 0.0055 - val_mean_absolute_error: 0.0855
# Epoch 67/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0050 - mean_absolute_error: 0.0817
# Epoch 67: val_loss did not improve from 0.00525
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0050 - mean_absolute_error: 0.0817 - val_loss: 0.0054 - val_mean_absolute_error: 0.0853
# Epoch 68/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0047 - mean_absolute_error: 0.0810
# Epoch 68: val_loss did not improve from 0.00525
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0047 - mean_absolute_error: 0.0810 - val_loss: 0.0058 - val_mean_absolute_error: 0.0904
# Epoch 69/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0046 - mean_absolute_error: 0.0799
# Epoch 69: val_loss improved from 0.00525 to 0.00521, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0046 - mean_absolute_error: 0.0799 - val_loss: 0.0052 - val_mean_absolute_error: 0.0825
# Epoch 70/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0046 - mean_absolute_error: 0.0784
# Epoch 70: val_loss improved from 0.00521 to 0.00500, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0046 - mean_absolute_error: 0.0784 - val_loss: 0.0050 - val_mean_absolute_error: 0.0807
# Epoch 71/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0057 - mean_absolute_error: 0.0815
# Epoch 71: val_loss improved from 0.00500 to 0.00491, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0057 - mean_absolute_error: 0.0815 - val_loss: 0.0049 - val_mean_absolute_error: 0.0794
# Epoch 72/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0052 - mean_absolute_error: 0.0837
# Epoch 72: val_loss did not improve from 0.00491
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0052 - mean_absolute_error: 0.0837 - val_loss: 0.0051 - val_mean_absolute_error: 0.0819
# Epoch 73/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0047 - mean_absolute_error: 0.0788
# Epoch 73: val_loss did not improve from 0.00491
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0047 - mean_absolute_error: 0.0788 - val_loss: 0.0053 - val_mean_absolute_error: 0.0824
# Epoch 74/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0043 - mean_absolute_error: 0.0723
# Epoch 74: val_loss did not improve from 0.00491
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0043 - mean_absolute_error: 0.0723 - val_loss: 0.0077 - val_mean_absolute_error: 0.1040
# Epoch 75/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0057 - mean_absolute_error: 0.0855
# Epoch 75: val_loss did not improve from 0.00491
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0057 - mean_absolute_error: 0.0855 - val_loss: 0.0052 - val_mean_absolute_error: 0.0806
# Epoch 76/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0041 - mean_absolute_error: 0.0723
# Epoch 76: val_loss did not improve from 0.00491
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0041 - mean_absolute_error: 0.0723 - val_loss: 0.0054 - val_mean_absolute_error: 0.0857
# Epoch 77/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0047 - mean_absolute_error: 0.0808
# Epoch 77: val_loss improved from 0.00491 to 0.00488, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0047 - mean_absolute_error: 0.0808 - val_loss: 0.0049 - val_mean_absolute_error: 0.0798
# Epoch 78/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0045 - mean_absolute_error: 0.0753
# Epoch 78: val_loss did not improve from 0.00488
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0045 - mean_absolute_error: 0.0753 - val_loss: 0.0051 - val_mean_absolute_error: 0.0784
# Epoch 79/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0047 - mean_absolute_error: 0.0752
# Epoch 79: val_loss did not improve from 0.00488
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0047 - mean_absolute_error: 0.0752 - val_loss: 0.0057 - val_mean_absolute_error: 0.0888
# Epoch 80/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0046 - mean_absolute_error: 0.0785
# Epoch 80: val_loss improved from 0.00488 to 0.00442, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0046 - mean_absolute_error: 0.0785 - val_loss: 0.0044 - val_mean_absolute_error: 0.0751
# Epoch 81/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0041 - mean_absolute_error: 0.0727
# Epoch 81: val_loss improved from 0.00442 to 0.00427, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0041 - mean_absolute_error: 0.0727 - val_loss: 0.0043 - val_mean_absolute_error: 0.0729
# Epoch 82/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0037 - mean_absolute_error: 0.0695
# Epoch 82: val_loss did not improve from 0.00427
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0037 - mean_absolute_error: 0.0695 - val_loss: 0.0047 - val_mean_absolute_error: 0.0790
# Epoch 83/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0038 - mean_absolute_error: 0.0723
# Epoch 83: val_loss did not improve from 0.00427
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0038 - mean_absolute_error: 0.0723 - val_loss: 0.0050 - val_mean_absolute_error: 0.0795
# Epoch 84/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0043 - mean_absolute_error: 0.0746
# Epoch 84: val_loss did not improve from 0.00427
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0043 - mean_absolute_error: 0.0746 - val_loss: 0.0046 - val_mean_absolute_error: 0.0751
# Epoch 85/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0037 - mean_absolute_error: 0.0669
# Epoch 85: val_loss did not improve from 0.00427
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0037 - mean_absolute_error: 0.0669 - val_loss: 0.0043 - val_mean_absolute_error: 0.0732
# Epoch 86/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0039 - mean_absolute_error: 0.0721
# Epoch 86: val_loss improved from 0.00427 to 0.00401, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0039 - mean_absolute_error: 0.0721 - val_loss: 0.0040 - val_mean_absolute_error: 0.0686
# Epoch 87/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0040 - mean_absolute_error: 0.0699
# Epoch 87: val_loss did not improve from 0.00401
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0040 - mean_absolute_error: 0.0699 - val_loss: 0.0041 - val_mean_absolute_error: 0.0687
# Epoch 88/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0042 - mean_absolute_error: 0.0724
# Epoch 88: val_loss did not improve from 0.00401
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0042 - mean_absolute_error: 0.0724 - val_loss: 0.0042 - val_mean_absolute_error: 0.0700
# Epoch 89/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0040 - mean_absolute_error: 0.0697
# Epoch 89: val_loss did not improve from 0.00401
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0040 - mean_absolute_error: 0.0697 - val_loss: 0.0043 - val_mean_absolute_error: 0.0729
# Epoch 90/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0039 - mean_absolute_error: 0.0711
# Epoch 90: val_loss did not improve from 0.00401
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0039 - mean_absolute_error: 0.0711 - val_loss: 0.0041 - val_mean_absolute_error: 0.0700
# Epoch 91/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0038 - mean_absolute_error: 0.0671
# Epoch 91: val_loss did not improve from 0.00401
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0038 - mean_absolute_error: 0.0671 - val_loss: 0.0042 - val_mean_absolute_error: 0.0699
# Epoch 92/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0619
# Epoch 92: val_loss did not improve from 0.00401
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0030 - mean_absolute_error: 0.0619 - val_loss: 0.0040 - val_mean_absolute_error: 0.0698
# Epoch 93/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0036 - mean_absolute_error: 0.0657
# Epoch 93: val_loss improved from 0.00401 to 0.00395, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0036 - mean_absolute_error: 0.0657 - val_loss: 0.0040 - val_mean_absolute_error: 0.0691
# Epoch 94/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0622
# Epoch 94: val_loss did not improve from 0.00395
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0030 - mean_absolute_error: 0.0622 - val_loss: 0.0041 - val_mean_absolute_error: 0.0710
# Epoch 95/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0035 - mean_absolute_error: 0.0662
# Epoch 95: val_loss did not improve from 0.00395
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0035 - mean_absolute_error: 0.0662 - val_loss: 0.0042 - val_mean_absolute_error: 0.0705
# Epoch 96/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0037 - mean_absolute_error: 0.0673
# Epoch 96: val_loss did not improve from 0.00395
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0037 - mean_absolute_error: 0.0673 - val_loss: 0.0042 - val_mean_absolute_error: 0.0732
# Epoch 97/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0037 - mean_absolute_error: 0.0701
# Epoch 97: val_loss did not improve from 0.00395
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0037 - mean_absolute_error: 0.0701 - val_loss: 0.0040 - val_mean_absolute_error: 0.0671
# Epoch 98/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0624
# Epoch 98: val_loss did not improve from 0.00395
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0030 - mean_absolute_error: 0.0624 - val_loss: 0.0049 - val_mean_absolute_error: 0.0800
# Epoch 99/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0037 - mean_absolute_error: 0.0687
# Epoch 99: val_loss did not improve from 0.00395
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0037 - mean_absolute_error: 0.0687 - val_loss: 0.0042 - val_mean_absolute_error: 0.0691
# Epoch 100/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0038 - mean_absolute_error: 0.0680
# Epoch 100: val_loss did not improve from 0.00395
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0038 - mean_absolute_error: 0.0680 - val_loss: 0.0041 - val_mean_absolute_error: 0.0677
# Epoch 101/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0640
# Epoch 101: val_loss did not improve from 0.00395
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0029 - mean_absolute_error: 0.0640 - val_loss: 0.0051 - val_mean_absolute_error: 0.0817
# Epoch 102/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0035 - mean_absolute_error: 0.0656
# Epoch 102: val_loss did not improve from 0.00395
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0035 - mean_absolute_error: 0.0656 - val_loss: 0.0041 - val_mean_absolute_error: 0.0703
# Epoch 103/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0032 - mean_absolute_error: 0.0641
# Epoch 103: val_loss improved from 0.00395 to 0.00389, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0032 - mean_absolute_error: 0.0641 - val_loss: 0.0039 - val_mean_absolute_error: 0.0685
# Epoch 104/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0609
# Epoch 104: val_loss improved from 0.00389 to 0.00387, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0029 - mean_absolute_error: 0.0609 - val_loss: 0.0039 - val_mean_absolute_error: 0.0687
# Epoch 105/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0594
# Epoch 105: val_loss did not improve from 0.00387
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0029 - mean_absolute_error: 0.0594 - val_loss: 0.0039 - val_mean_absolute_error: 0.0701
# Epoch 106/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0615
# Epoch 106: val_loss improved from 0.00387 to 0.00378, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0030 - mean_absolute_error: 0.0615 - val_loss: 0.0038 - val_mean_absolute_error: 0.0679
# Epoch 107/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0576
# Epoch 107: val_loss did not improve from 0.00378
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0026 - mean_absolute_error: 0.0576 - val_loss: 0.0038 - val_mean_absolute_error: 0.0679
# Epoch 108/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0023 - mean_absolute_error: 0.0571
# Epoch 108: val_loss improved from 0.00378 to 0.00372, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0023 - mean_absolute_error: 0.0571 - val_loss: 0.0037 - val_mean_absolute_error: 0.0665
# Epoch 109/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0596
# Epoch 109: val_loss improved from 0.00372 to 0.00368, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0029 - mean_absolute_error: 0.0596 - val_loss: 0.0037 - val_mean_absolute_error: 0.0655
# Epoch 110/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0557
# Epoch 110: val_loss improved from 0.00368 to 0.00362, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0027 - mean_absolute_error: 0.0557 - val_loss: 0.0036 - val_mean_absolute_error: 0.0644
# Epoch 111/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0549
# Epoch 111: val_loss improved from 0.00362 to 0.00355, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0027 - mean_absolute_error: 0.0549 - val_loss: 0.0036 - val_mean_absolute_error: 0.0643
# Epoch 112/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0028 - mean_absolute_error: 0.0606
# Epoch 112: val_loss improved from 0.00355 to 0.00352, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0028 - mean_absolute_error: 0.0606 - val_loss: 0.0035 - val_mean_absolute_error: 0.0644
# Epoch 113/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0033 - mean_absolute_error: 0.0632
# Epoch 113: val_loss did not improve from 0.00352
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0033 - mean_absolute_error: 0.0632 - val_loss: 0.0039 - val_mean_absolute_error: 0.0694
# Epoch 114/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0040 - mean_absolute_error: 0.0731
# Epoch 114: val_loss improved from 0.00352 to 0.00334, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0040 - mean_absolute_error: 0.0731 - val_loss: 0.0033 - val_mean_absolute_error: 0.0640
# Epoch 115/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0033 - mean_absolute_error: 0.0614
# Epoch 115: val_loss did not improve from 0.00334
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0033 - mean_absolute_error: 0.0614 - val_loss: 0.0034 - val_mean_absolute_error: 0.0618
# Epoch 116/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0610
# Epoch 116: val_loss did not improve from 0.00334
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0029 - mean_absolute_error: 0.0610 - val_loss: 0.0040 - val_mean_absolute_error: 0.0739
# Epoch 117/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0619
# Epoch 117: val_loss did not improve from 0.00334
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0030 - mean_absolute_error: 0.0619 - val_loss: 0.0047 - val_mean_absolute_error: 0.0754
# Epoch 118/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0032 - mean_absolute_error: 0.0630
# Epoch 118: val_loss improved from 0.00334 to 0.00320, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0032 - mean_absolute_error: 0.0630 - val_loss: 0.0032 - val_mean_absolute_error: 0.0621
# Epoch 119/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0542
# Epoch 119: val_loss improved from 0.00320 to 0.00309, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0025 - mean_absolute_error: 0.0542 - val_loss: 0.0031 - val_mean_absolute_error: 0.0612
# Epoch 120/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0578
# Epoch 120: val_loss improved from 0.00309 to 0.00299, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0027 - mean_absolute_error: 0.0578 - val_loss: 0.0030 - val_mean_absolute_error: 0.0603
# Epoch 121/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0563
# Epoch 121: val_loss did not improve from 0.00299
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0024 - mean_absolute_error: 0.0563 - val_loss: 0.0033 - val_mean_absolute_error: 0.0643
# Epoch 122/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0573
# Epoch 122: val_loss did not improve from 0.00299
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0025 - mean_absolute_error: 0.0573 - val_loss: 0.0040 - val_mean_absolute_error: 0.0685
# Epoch 123/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0031 - mean_absolute_error: 0.0600
# Epoch 123: val_loss did not improve from 0.00299
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0031 - mean_absolute_error: 0.0600 - val_loss: 0.0031 - val_mean_absolute_error: 0.0621
# Epoch 124/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0534
# Epoch 124: val_loss improved from 0.00299 to 0.00292, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0022 - mean_absolute_error: 0.0534 - val_loss: 0.0029 - val_mean_absolute_error: 0.0609
# Epoch 125/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0549
# Epoch 125: val_loss improved from 0.00292 to 0.00289, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0025 - mean_absolute_error: 0.0549 - val_loss: 0.0029 - val_mean_absolute_error: 0.0600
# Epoch 126/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0545
# Epoch 126: val_loss did not improve from 0.00289
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0024 - mean_absolute_error: 0.0545 - val_loss: 0.0032 - val_mean_absolute_error: 0.0632
# Epoch 127/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0020 - mean_absolute_error: 0.0499
# Epoch 127: val_loss did not improve from 0.00289
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0020 - mean_absolute_error: 0.0499 - val_loss: 0.0038 - val_mean_absolute_error: 0.0679
# Epoch 128/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0612
# Epoch 128: val_loss did not improve from 0.00289
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0027 - mean_absolute_error: 0.0612 - val_loss: 0.0046 - val_mean_absolute_error: 0.0787
# Epoch 129/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0039 - mean_absolute_error: 0.0697
# Epoch 129: val_loss did not improve from 0.00289
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0039 - mean_absolute_error: 0.0697 - val_loss: 0.0031 - val_mean_absolute_error: 0.0624
# Epoch 130/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0502
# Epoch 130: val_loss did not improve from 0.00289
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0022 - mean_absolute_error: 0.0502 - val_loss: 0.0037 - val_mean_absolute_error: 0.0663
# Epoch 131/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0031 - mean_absolute_error: 0.0649
# Epoch 131: val_loss did not improve from 0.00289
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0031 - mean_absolute_error: 0.0649 - val_loss: 0.0039 - val_mean_absolute_error: 0.0699
# Epoch 132/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0611
# Epoch 132: val_loss did not improve from 0.00289
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0029 - mean_absolute_error: 0.0611 - val_loss: 0.0030 - val_mean_absolute_error: 0.0618
# Epoch 133/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0595
# Epoch 133: val_loss improved from 0.00289 to 0.00285, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0029 - mean_absolute_error: 0.0595 - val_loss: 0.0028 - val_mean_absolute_error: 0.0608
# Epoch 134/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0607
# Epoch 134: val_loss improved from 0.00285 to 0.00277, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0030 - mean_absolute_error: 0.0607 - val_loss: 0.0028 - val_mean_absolute_error: 0.0589
# Epoch 135/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0034 - mean_absolute_error: 0.0651
# Epoch 135: val_loss did not improve from 0.00277
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0034 - mean_absolute_error: 0.0651 - val_loss: 0.0030 - val_mean_absolute_error: 0.0611
# Epoch 136/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0599
# Epoch 136: val_loss did not improve from 0.00277
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0027 - mean_absolute_error: 0.0599 - val_loss: 0.0029 - val_mean_absolute_error: 0.0585
# Epoch 137/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0020 - mean_absolute_error: 0.0502
# Epoch 137: val_loss did not improve from 0.00277
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0020 - mean_absolute_error: 0.0502 - val_loss: 0.0031 - val_mean_absolute_error: 0.0628
# Epoch 138/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0571
# Epoch 138: val_loss did not improve from 0.00277
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0026 - mean_absolute_error: 0.0571 - val_loss: 0.0031 - val_mean_absolute_error: 0.0627
# Epoch 139/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0565
# Epoch 139: val_loss did not improve from 0.00277
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0026 - mean_absolute_error: 0.0565 - val_loss: 0.0035 - val_mean_absolute_error: 0.0667
# Epoch 140/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0552
# Epoch 140: val_loss did not improve from 0.00277
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0026 - mean_absolute_error: 0.0552 - val_loss: 0.0030 - val_mean_absolute_error: 0.0620
# Epoch 141/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0567
# Epoch 141: val_loss did not improve from 0.00277
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0025 - mean_absolute_error: 0.0567 - val_loss: 0.0036 - val_mean_absolute_error: 0.0673
# Epoch 142/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0028 - mean_absolute_error: 0.0590
# Epoch 142: val_loss did not improve from 0.00277
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0028 - mean_absolute_error: 0.0590 - val_loss: 0.0031 - val_mean_absolute_error: 0.0634
# Epoch 143/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0595
# Epoch 143: val_loss did not improve from 0.00277
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0027 - mean_absolute_error: 0.0595 - val_loss: 0.0028 - val_mean_absolute_error: 0.0586
# Epoch 144/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0021 - mean_absolute_error: 0.0515
# Epoch 144: val_loss did not improve from 0.00277
# ...
# Epoch 351/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - mean_absolute_error: 0.0395
# Epoch 351: val_loss did not improve from 0.00144
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0013 - mean_absolute_error: 0.0395 - val_loss: 0.0019 - val_mean_absolute_error: 0.0517
# Epoch 352/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - mean_absolute_error: 0.0417
# Epoch 352: val_loss did not improve from 0.00144
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0013 - mean_absolute_error: 0.0417 - val_loss: 0.0020 - val_mean_absolute_error: 0.0501
# Epoch 353/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - mean_absolute_error: 0.0381
# Epoch 353: val_loss did not improve from 0.00144
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0012 - mean_absolute_error: 0.0381 - val_loss: 0.0015 - val_mean_absolute_error: 0.0460
# Epoch 354/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - mean_absolute_error: 0.0396
# Epoch 354: val_loss improved from 0.00144 to 0.00143, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0013 - mean_absolute_error: 0.0396 - val_loss: 0.0014 - val_mean_absolute_error: 0.0409
# Epoch 355/400
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0012 - mean_absolute_error: 0.0392
# Epoch 355: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0013 - mean_absolute_error: 0.0395 - val_loss: 0.0015 - val_mean_absolute_error: 0.0427
# Epoch 356/400
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0011 - mean_absolute_error: 0.0378
# Epoch 356: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0010 - mean_absolute_error: 0.0367 - val_loss: 0.0017 - val_mean_absolute_error: 0.0487
# Epoch 357/400
# 3/3 [==============================] - ETA: 0s - loss: 9.4023e-04 - mean_absolute_error: 0.0350
# Epoch 357: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 68ms/step - loss: 9.4023e-04 - mean_absolute_error: 0.0350 - val_loss: 0.0016 - val_mean_absolute_error: 0.0434
# Epoch 358/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - mean_absolute_error: 0.0388
# Epoch 358: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0012 - mean_absolute_error: 0.0388 - val_loss: 0.0016 - val_mean_absolute_error: 0.0434
# Epoch 359/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - mean_absolute_error: 0.0373
# Epoch 359: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0011 - mean_absolute_error: 0.0373 - val_loss: 0.0015 - val_mean_absolute_error: 0.0428
# Epoch 360/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0010 - mean_absolute_error: 0.0375
# Epoch 360: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0010 - mean_absolute_error: 0.0375 - val_loss: 0.0016 - val_mean_absolute_error: 0.0446
# Epoch 361/400
# 3/3 [==============================] - ETA: 0s - loss: 8.7612e-04 - mean_absolute_error: 0.0318
# Epoch 361: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 65ms/step - loss: 8.7612e-04 - mean_absolute_error: 0.0318 - val_loss: 0.0016 - val_mean_absolute_error: 0.0452
# Epoch 362/400
# 3/3 [==============================] - ETA: 0s - loss: 9.0409e-04 - mean_absolute_error: 0.0327
# Epoch 362: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 63ms/step - loss: 9.0409e-04 - mean_absolute_error: 0.0327 - val_loss: 0.0017 - val_mean_absolute_error: 0.0470
# Epoch 363/400
# 3/3 [==============================] - ETA: 0s - loss: 8.0409e-04 - mean_absolute_error: 0.0312
# Epoch 363: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 57ms/step - loss: 8.0409e-04 - mean_absolute_error: 0.0312 - val_loss: 0.0015 - val_mean_absolute_error: 0.0422
# Epoch 364/400
# 3/3 [==============================] - ETA: 0s - loss: 8.6760e-04 - mean_absolute_error: 0.0326
# Epoch 364: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 55ms/step - loss: 8.6760e-04 - mean_absolute_error: 0.0326 - val_loss: 0.0015 - val_mean_absolute_error: 0.0420
# Epoch 365/400
# 3/3 [==============================] - ETA: 0s - loss: 8.9837e-04 - mean_absolute_error: 0.0332
# Epoch 365: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 59ms/step - loss: 8.9837e-04 - mean_absolute_error: 0.0332 - val_loss: 0.0017 - val_mean_absolute_error: 0.0448
# Epoch 366/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - mean_absolute_error: 0.0375
# Epoch 366: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0012 - mean_absolute_error: 0.0375 - val_loss: 0.0016 - val_mean_absolute_error: 0.0434
# Epoch 367/400
# 3/3 [==============================] - ETA: 0s - loss: 8.9386e-04 - mean_absolute_error: 0.0338
# Epoch 367: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 57ms/step - loss: 8.9386e-04 - mean_absolute_error: 0.0338 - val_loss: 0.0015 - val_mean_absolute_error: 0.0426
# Epoch 368/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - mean_absolute_error: 0.0374
# Epoch 368: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0012 - mean_absolute_error: 0.0374 - val_loss: 0.0016 - val_mean_absolute_error: 0.0442
# Epoch 369/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0010 - mean_absolute_error: 0.0351
# Epoch 369: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0010 - mean_absolute_error: 0.0351 - val_loss: 0.0016 - val_mean_absolute_error: 0.0458
# Epoch 370/400
# 3/3 [==============================] - ETA: 0s - loss: 8.7491e-04 - mean_absolute_error: 0.0334
# Epoch 370: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 61ms/step - loss: 8.7491e-04 - mean_absolute_error: 0.0334 - val_loss: 0.0016 - val_mean_absolute_error: 0.0470
# Epoch 371/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0010 - mean_absolute_error: 0.0368
# Epoch 371: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0010 - mean_absolute_error: 0.0368 - val_loss: 0.0015 - val_mean_absolute_error: 0.0428
# Epoch 372/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - mean_absolute_error: 0.0383
# Epoch 372: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0012 - mean_absolute_error: 0.0383 - val_loss: 0.0016 - val_mean_absolute_error: 0.0446
# Epoch 373/400
# 3/3 [==============================] - ETA: 0s - loss: 8.4674e-04 - mean_absolute_error: 0.0337
# Epoch 373: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 58ms/step - loss: 8.4674e-04 - mean_absolute_error: 0.0337 - val_loss: 0.0016 - val_mean_absolute_error: 0.0462
# Epoch 374/400
# 3/3 [==============================] - ETA: 0s - loss: 8.6102e-04 - mean_absolute_error: 0.0323
# Epoch 374: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 63ms/step - loss: 8.6102e-04 - mean_absolute_error: 0.0323 - val_loss: 0.0016 - val_mean_absolute_error: 0.0463
# Epoch 375/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - mean_absolute_error: 0.0353
# Epoch 375: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0011 - mean_absolute_error: 0.0353 - val_loss: 0.0017 - val_mean_absolute_error: 0.0464
# Epoch 376/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0010 - mean_absolute_error: 0.0349
# Epoch 376: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0010 - mean_absolute_error: 0.0349 - val_loss: 0.0017 - val_mean_absolute_error: 0.0473
# Epoch 377/400
# 3/3 [==============================] - ETA: 0s - loss: 8.6523e-04 - mean_absolute_error: 0.0328
# Epoch 377: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 62ms/step - loss: 8.6523e-04 - mean_absolute_error: 0.0328 - val_loss: 0.0017 - val_mean_absolute_error: 0.0461
# Epoch 378/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - mean_absolute_error: 0.0387
# Epoch 378: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0013 - mean_absolute_error: 0.0387 - val_loss: 0.0016 - val_mean_absolute_error: 0.0444
# Epoch 379/400
# 3/3 [==============================] - ETA: 0s - loss: 9.3288e-04 - mean_absolute_error: 0.0337
# Epoch 379: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 63ms/step - loss: 9.3288e-04 - mean_absolute_error: 0.0337 - val_loss: 0.0015 - val_mean_absolute_error: 0.0437
# Epoch 380/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - mean_absolute_error: 0.0359
# Epoch 380: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0011 - mean_absolute_error: 0.0359 - val_loss: 0.0016 - val_mean_absolute_error: 0.0445
# Epoch 381/400
# 3/3 [==============================] - ETA: 0s - loss: 9.5625e-04 - mean_absolute_error: 0.0353
# Epoch 381: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 60ms/step - loss: 9.5625e-04 - mean_absolute_error: 0.0353 - val_loss: 0.0016 - val_mean_absolute_error: 0.0474
# Epoch 382/400
# 3/3 [==============================] - ETA: 0s - loss: 9.7168e-04 - mean_absolute_error: 0.0335
# Epoch 382: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 62ms/step - loss: 9.7168e-04 - mean_absolute_error: 0.0335 - val_loss: 0.0016 - val_mean_absolute_error: 0.0445
# Epoch 383/400
# 3/3 [==============================] - ETA: 0s - loss: 9.5582e-04 - mean_absolute_error: 0.0355
# Epoch 383: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 63ms/step - loss: 9.5582e-04 - mean_absolute_error: 0.0355 - val_loss: 0.0016 - val_mean_absolute_error: 0.0447
# Epoch 384/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - mean_absolute_error: 0.0363
# Epoch 384: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0011 - mean_absolute_error: 0.0363 - val_loss: 0.0016 - val_mean_absolute_error: 0.0445
# Epoch 385/400
# 3/3 [==============================] - ETA: 0s - loss: 7.7554e-04 - mean_absolute_error: 0.0320
# Epoch 385: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 62ms/step - loss: 7.7554e-04 - mean_absolute_error: 0.0320 - val_loss: 0.0016 - val_mean_absolute_error: 0.0454
# Epoch 386/400
# 3/3 [==============================] - ETA: 0s - loss: 7.3724e-04 - mean_absolute_error: 0.0313
# Epoch 386: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 62ms/step - loss: 7.3724e-04 - mean_absolute_error: 0.0313 - val_loss: 0.0017 - val_mean_absolute_error: 0.0456
# Epoch 387/400
# 3/3 [==============================] - ETA: 0s - loss: 9.6710e-04 - mean_absolute_error: 0.0350
# Epoch 387: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 61ms/step - loss: 9.6710e-04 - mean_absolute_error: 0.0350 - val_loss: 0.0017 - val_mean_absolute_error: 0.0455
# Epoch 388/400
# 3/3 [==============================] - ETA: 0s - loss: 9.5178e-04 - mean_absolute_error: 0.0331
# Epoch 388: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 57ms/step - loss: 9.5178e-04 - mean_absolute_error: 0.0331 - val_loss: 0.0017 - val_mean_absolute_error: 0.0467
# Epoch 389/400
# 3/3 [==============================] - ETA: 0s - loss: 7.7480e-04 - mean_absolute_error: 0.0310
# Epoch 389: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 58ms/step - loss: 7.7480e-04 - mean_absolute_error: 0.0310 - val_loss: 0.0019 - val_mean_absolute_error: 0.0516
# Epoch 390/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - mean_absolute_error: 0.0347
# Epoch 390: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0011 - mean_absolute_error: 0.0347 - val_loss: 0.0017 - val_mean_absolute_error: 0.0483
# Epoch 391/400
# 3/3 [==============================] - ETA: 0s - loss: 8.3746e-04 - mean_absolute_error: 0.0315
# Epoch 391: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 72ms/step - loss: 8.3746e-04 - mean_absolute_error: 0.0315 - val_loss: 0.0016 - val_mean_absolute_error: 0.0451
# Epoch 392/400
# 3/3 [==============================] - ETA: 0s - loss: 9.9182e-04 - mean_absolute_error: 0.0337
# Epoch 392: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 64ms/step - loss: 9.9182e-04 - mean_absolute_error: 0.0337 - val_loss: 0.0016 - val_mean_absolute_error: 0.0463
# Epoch 393/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - mean_absolute_error: 0.0376
# Epoch 393: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0013 - mean_absolute_error: 0.0376 - val_loss: 0.0016 - val_mean_absolute_error: 0.0440
# Epoch 394/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0010 - mean_absolute_error: 0.0364
# Epoch 394: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0010 - mean_absolute_error: 0.0364 - val_loss: 0.0015 - val_mean_absolute_error: 0.0422
# Epoch 395/400
# 3/3 [==============================] - ETA: 0s - loss: 9.2534e-04 - mean_absolute_error: 0.0344
# Epoch 395: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 59ms/step - loss: 9.2534e-04 - mean_absolute_error: 0.0344 - val_loss: 0.0018 - val_mean_absolute_error: 0.0477
# Epoch 396/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - mean_absolute_error: 0.0373
# Epoch 396: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0012 - mean_absolute_error: 0.0373 - val_loss: 0.0018 - val_mean_absolute_error: 0.0481
# Epoch 397/400
# 3/3 [==============================] - ETA: 0s - loss: 0.0010 - mean_absolute_error: 0.0369
# Epoch 397: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0010 - mean_absolute_error: 0.0369 - val_loss: 0.0019 - val_mean_absolute_error: 0.0501
# Epoch 398/400
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0011 - mean_absolute_error: 0.0374
# Epoch 398: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0011 - mean_absolute_error: 0.0371 - val_loss: 0.0016 - val_mean_absolute_error: 0.0451
# Epoch 399/400
# 3/3 [==============================] - ETA: 0s - loss: 8.4219e-04 - mean_absolute_error: 0.0327
# Epoch 399: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 63ms/step - loss: 8.4219e-04 - mean_absolute_error: 0.0327 - val_loss: 0.0015 - val_mean_absolute_error: 0.0425
# Epoch 400/400
# 3/3 [==============================] - ETA: 0s - loss: 9.4906e-04 - mean_absolute_error: 0.0340
# Epoch 400: val_loss did not improve from 0.00143
# 3/3 [==============================] - 0s 58ms/step - loss: 9.4906e-04 - mean_absolute_error: 0.0340 - val_loss: 0.0015 - val_mean_absolute_error: 0.0434
# [*********************100%***********************]  1 of 1 completed
# Mean Absolute Error: 357.44515143991197
# 1/1 [==============================] - 1s 911ms/step
# Future price after 1 days is 379.75$
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 1: Accuracy Score: 0.8888888888888888

# %%
def predict(model, data):
    last_sequence = data["last_sequence"][-N_STEPS:]
    column_scaler = data["column_scaler"]
    last_sequence = last_sequence.reshape((last_sequence.shape[1], last_sequence.shape[0]))
    last_sequence = np.expand_dims(last_sequence, axis=0)
    # get the prediction (scaled from 0 to 1)
    prediction = model.predict(last_sequence)
    # get the price (by inverting the scaling)
    predicted_price = column_scaler["Close"].inverse_transform(prediction)[0][0]
    return predicted_price

# predict the future price
future_price = predict(model, data)
print(f"Future price after {LOOKUP_STEP} days is {future_price:.2f}$")

# %%
def plot_graph(model, data):
    y_test = data["y_test"]
    X_test = data["X_test"]
    y_pred = model.predict(X_test)
    y_test = np.squeeze(data["column_scaler"]["Close"].inverse_transform(np.expand_dims(y_test, axis=0)))
    y_pred = np.squeeze(data["column_scaler"]["Close"].inverse_transform(y_pred))
    # currently last 200 days
    plt.plot(y_test[-200:], c='b')
    plt.plot(y_pred[-200:], c='r')
    plt.xlabel("Days")
    plt.ylabel("Price")
    plt.legend(["Actual Price", "Predicted Price"])
    plt.show()

plot_graph(model, data)

# %%
def accuracy(model, data):
    y_test = data["y_test"]
    X_test = data["X_test"]
    y_pred = model.predict(X_test)
    y_test = np.squeeze(data["column_scaler"]["Close"].inverse_transform(np.expand_dims(y_test, axis=0)))
    y_pred = np.squeeze(data["column_scaler"]["Close"].inverse_transform(y_pred))
    y_pred = list(map(lambda current, future: int(float(future) > float(current)), y_test[:-LOOKUP_STEP], y_pred[LOOKUP_STEP:]))
    y_test = list(map(lambda current, future: int(float(future) > float(current)), y_test[:-LOOKUP_STEP], y_test[LOOKUP_STEP:]))
    return accuracy_score(y_test, y_pred)

print(str(LOOKUP_STEP) + ":", "Accuracy Score:", accuracy(model, data))
