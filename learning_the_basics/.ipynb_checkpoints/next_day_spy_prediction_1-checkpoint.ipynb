# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random
from collections import deque

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import yfinance as yf

# https://www.thepythoncode.com/article/stock-price-prediction-in-python-using-tensorflow-2-and-keras

#try changing around the optimizer

# Reproducability
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %%
#units = neurons
def load_data(ticker, period, interval, n_steps=50, scale=True, shuffle=True, lookup_step=1, test_size=.2,
              feature_columns=['Close', 'Volume', 'Open', 'High', 'Low']):
    '''
    :param ticker: Ticker you want to load, dtype: str
    :param period: Time period you want data from, dtype: str(options in program)
    :param interval: Interval for data, dtype:str
    :param n_steps: Past sequence len used to predict, default = 50, dtype: int
    :param scale: Whether to scale data b/w 0 and 1, default = True, dtype: Bool
    :param shuffle: Whether to shuffle data, default = True, dtyper: Bool
    :param lookup_step: Future lookup step to predict, default = 1(next day), dtype:int
    :param test_size: ratio for test data, default is .2 (20% test data), dtype: float
    :param feature_columns: list of features fed into the model, default is OHLCV, dtype: list
    :return:
    '''
    df = yf.download(tickers=ticker, period=period, interval=interval,
                     group_by='ticker',
                     # adjust all OHLC automatically
                     auto_adjust=True, prepost=True, threads=True, proxy=None)

    #print("removing last day for testing by damian")
    #df = df.iloc[:-16 , :].copy()
    #print(df.tail())
    
    
    result = {}
    result['df'] = df.copy()

    for col in feature_columns:
        assert col in df.columns, f"'{col}' does not exist in the dataframe."
    if scale:
        column_scaler = {}
        # scale the data (prices) from 0 to 1
        for column in feature_columns:
            scaler = preprocessing.MinMaxScaler()
            df[column] = scaler.fit_transform(np.expand_dims(df[column].values, axis=1))
            column_scaler[column] = scaler
        # add the MinMaxScaler instances to the result returned
        result["column_scaler"] = column_scaler
    # add the target column (label) by shifting by `lookup_step`
    df['future'] = df['Close'].shift(-lookup_step)
    # last `lookup_step` columns contains NaN in future column
    # get them before droping NaNs
    last_sequence = np.array(df[feature_columns].tail(lookup_step))
    # drop NaNs
    df.dropna(inplace=True)
    sequence_data = []
    sequences = deque(maxlen=n_steps)
    for entry, target in zip(df[feature_columns].values, df['future'].values):
        sequences.append(entry)
        if len(sequences) == n_steps:
            sequence_data.append([np.array(sequences), target])
    # get the last sequence by appending the last `n_step` sequence with `lookup_step` sequence
    # for instance, if n_steps=50 and lookup_step=10, last_sequence should be of 60 (that is 50+10) length
    # this last_sequence will be used to predict future stock prices not available in the dataset
    last_sequence = list(sequences) + list(last_sequence)
    last_sequence = np.array(last_sequence)
    # add to result
    result['last_sequence'] = last_sequence
    # construct the X's and y's
    X, y = [], []
    for seq, target in sequence_data:
        X.append(seq)
        y.append(target)
    # convert to numpy arrays
    X = np.array(X)
    y = np.array(y)
    # reshape X to fit the neural network
    X = X.reshape((X.shape[0], X.shape[2], X.shape[1]))
    # split the dataset
    result["X_train"], result["X_test"], result["y_train"], result["y_test"] = train_test_split(X, y,
                                                                               test_size=test_size, shuffle=shuffle)
    # return the result
    return result

#Again, this function is flexible too, and you can change the number of layers, dropout rate, the RNN cell, loss, and the optimizer used to compile the model.

#The above function constructs an RNN with a dense layer as an output layer with one neuron. This model requires a sequence of features of sequence_length (in this case, we will pass 50 or 100) consecutive time steps (which are days in this dataset) and outputs a single value which indicates the price of the next time step.

#It also accepts n_features as an argument, which is the number of features we will pass on each sequence, in our case, we'll pass adjclose, open, high, low and volume columns (i.e 5 features).

#You can tweak the default parameters as you wish, n_layers is the number of RNN layers you want to stack, dropout is the dropout rate after each RNN layer, units are the number of RNN cell units (whether it is LSTM, SimpleRNN, or GRU), bidirectional is a boolean that indicates whether to use bidirectional RNNs, experiment with those!


def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="adam", bidirectional=False):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation="linear"))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
N_STEPS = 70
# valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
PERIOD = '2y'
# valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
INTERVAL = '1d'
# Lookup step, 1 is the next day
LOOKUP_STEP = 1
# test ratio size, 0.2 is 20%
TEST_SIZE = 0.3
# features to use
FEATURE_COLUMNS = ["Close", "Volume", "Open", "High", "Low"]
# date now
date_now = time.strftime("%Y-%m-%d")

# > model parameters <
N_LAYERS = 3
#Type of model
CELL = LSTM
# Number of neurons
UNITS = 256
# Dropout rate
DROPOUT = 0.4
# whether to use bidirectional RNNs
BIDIRECTIONAL = False

# > training parameters <
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 200
ticker = "SPY"

#save model
model_name = f"{date_now}_{ticker}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-seq-{N_STEPS}-step-{LOOKUP_STEP}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

# folders that store results
if not os.path.isdir("results"):
    os.mkdir("results")
if not os.path.isdir("logs"):
    os.mkdir("logs")
if not os.path.isdir("data"):
    os.mkdir("data")

data = load_data(ticker, PERIOD, INTERVAL, N_STEPS, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE, feature_columns=FEATURE_COLUMNS)
# save the dataframe
data["df"].to_csv()
# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))
history = model.fit(data["X_train"], data["y_train"],
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(data["X_test"], data["y_test"]),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)
model.save(os.path.join("results", model_name) + ".h5")

# >> Testing the Model <<

data = load_data(ticker, PERIOD, INTERVAL, N_STEPS, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE,
                feature_columns=FEATURE_COLUMNS, shuffle=False)
# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
model_path = os.path.join("results", model_name) + ".h5"
model.load_weights(model_path)

# evaluate the model
mse, mae = model.evaluate(data["X_test"], data["y_test"], verbose=0)
# calculate the mean absolute error (inverse scaling)
mean_absolute_error = data["column_scaler"]["Close"].inverse_transform([[mae]])[0][0]
print("Mean Absolute Error:", mean_absolute_error)
# Out:
# [*********************100%***********************]  1 of 1 completed
# removing last day for testing by damian
#                   Open        High         Low       Close     Volume
# Date
# 2022-12-07  391.143858  393.831529  390.178291  391.362854   65927900
# 2022-12-08  393.333824  395.543648  391.472347  394.428772   60737900
# 2022-12-09  393.134716  395.802458  391.352889  391.482300   81367500
# 2022-12-12  392.308501  397.126404  391.611719  397.126404   75405800
# 2022-12-13  408.344888  408.613643  397.245861  400.132599  123782500
# Epoch 1/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0830 - mean_absolute_error: 0.3201
# Epoch 1: val_loss improved from inf to 0.03646, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 5s 277ms/step - loss: 0.0830 - mean_absolute_error: 0.3201 - val_loss: 0.0365 - val_mean_absolute_error: 0.2378
# Epoch 2/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0389 - mean_absolute_error: 0.2421
# Epoch 2: val_loss improved from 0.03646 to 0.01774, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 101ms/step - loss: 0.0389 - mean_absolute_error: 0.2421 - val_loss: 0.0177 - val_mean_absolute_error: 0.1458
# Epoch 3/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0236 - mean_absolute_error: 0.1633
# Epoch 3: val_loss improved from 0.01774 to 0.01637, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0236 - mean_absolute_error: 0.1633 - val_loss: 0.0164 - val_mean_absolute_error: 0.1558
# Epoch 4/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0214 - mean_absolute_error: 0.1752
# Epoch 4: val_loss improved from 0.01637 to 0.01600, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0214 - mean_absolute_error: 0.1752 - val_loss: 0.0160 - val_mean_absolute_error: 0.1555
# Epoch 5/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0195 - mean_absolute_error: 0.1611
# Epoch 5: val_loss improved from 0.01600 to 0.01523, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0195 - mean_absolute_error: 0.1611 - val_loss: 0.0152 - val_mean_absolute_error: 0.1435
# Epoch 6/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0189 - mean_absolute_error: 0.1628
# Epoch 6: val_loss did not improve from 0.01523
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0189 - mean_absolute_error: 0.1628 - val_loss: 0.0164 - val_mean_absolute_error: 0.1623
# Epoch 7/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0177 - mean_absolute_error: 0.1525
# Epoch 7: val_loss improved from 0.01523 to 0.01479, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0177 - mean_absolute_error: 0.1525 - val_loss: 0.0148 - val_mean_absolute_error: 0.1448
# Epoch 8/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0162 - mean_absolute_error: 0.1489
# Epoch 8: val_loss did not improve from 0.01479
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0162 - mean_absolute_error: 0.1489 - val_loss: 0.0157 - val_mean_absolute_error: 0.1597
# Epoch 9/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0147 - mean_absolute_error: 0.1459
# Epoch 9: val_loss improved from 0.01479 to 0.01463, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0147 - mean_absolute_error: 0.1459 - val_loss: 0.0146 - val_mean_absolute_error: 0.1472
# Epoch 10/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0140 - mean_absolute_error: 0.1401
# Epoch 10: val_loss did not improve from 0.01463
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0140 - mean_absolute_error: 0.1401 - val_loss: 0.0151 - val_mean_absolute_error: 0.1561
# Epoch 11/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0144 - mean_absolute_error: 0.1406
# Epoch 11: val_loss improved from 0.01463 to 0.01387, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0144 - mean_absolute_error: 0.1406 - val_loss: 0.0139 - val_mean_absolute_error: 0.1414
# Epoch 12/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0137 - mean_absolute_error: 0.1344
# Epoch 12: val_loss improved from 0.01387 to 0.01300, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0137 - mean_absolute_error: 0.1344 - val_loss: 0.0130 - val_mean_absolute_error: 0.1419
# Epoch 13/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0127 - mean_absolute_error: 0.1311
# Epoch 13: val_loss did not improve from 0.01300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0127 - mean_absolute_error: 0.1311 - val_loss: 0.0133 - val_mean_absolute_error: 0.1275
# Epoch 14/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0129 - mean_absolute_error: 0.1302
# Epoch 14: val_loss improved from 0.01300 to 0.01219, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0129 - mean_absolute_error: 0.1302 - val_loss: 0.0122 - val_mean_absolute_error: 0.1370
# Epoch 15/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0124 - mean_absolute_error: 0.1281
# Epoch 15: val_loss improved from 0.01219 to 0.01032, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0124 - mean_absolute_error: 0.1281 - val_loss: 0.0103 - val_mean_absolute_error: 0.1208
# Epoch 16/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0114 - mean_absolute_error: 0.1234
# Epoch 16: val_loss improved from 0.01032 to 0.00968, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0114 - mean_absolute_error: 0.1234 - val_loss: 0.0097 - val_mean_absolute_error: 0.1149
# Epoch 17/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0106 - mean_absolute_error: 0.1173
# Epoch 17: val_loss improved from 0.00968 to 0.00920, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0106 - mean_absolute_error: 0.1173 - val_loss: 0.0092 - val_mean_absolute_error: 0.1082
# Epoch 18/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0111 - mean_absolute_error: 0.1200
# Epoch 18: val_loss improved from 0.00920 to 0.00845, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0111 - mean_absolute_error: 0.1200 - val_loss: 0.0084 - val_mean_absolute_error: 0.1066
# Epoch 19/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0116 - mean_absolute_error: 0.1215
# Epoch 19: val_loss did not improve from 0.00845
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0116 - mean_absolute_error: 0.1215 - val_loss: 0.0093 - val_mean_absolute_error: 0.1195
# Epoch 20/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0108 - mean_absolute_error: 0.1184
# Epoch 20: val_loss improved from 0.00845 to 0.00723, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0108 - mean_absolute_error: 0.1184 - val_loss: 0.0072 - val_mean_absolute_error: 0.0974
# Epoch 21/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0090 - mean_absolute_error: 0.1073
# Epoch 21: val_loss did not improve from 0.00723
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0090 - mean_absolute_error: 0.1073 - val_loss: 0.0079 - val_mean_absolute_error: 0.0905
# Epoch 22/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0085 - mean_absolute_error: 0.1049
# Epoch 22: val_loss improved from 0.00723 to 0.00642, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0085 - mean_absolute_error: 0.1049 - val_loss: 0.0064 - val_mean_absolute_error: 0.0931
# Epoch 23/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0089 - mean_absolute_error: 0.1073
# Epoch 23: val_loss improved from 0.00642 to 0.00608, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0089 - mean_absolute_error: 0.1073 - val_loss: 0.0061 - val_mean_absolute_error: 0.0937
# Epoch 24/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0078 - mean_absolute_error: 0.0990
# Epoch 24: val_loss did not improve from 0.00608
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0078 - mean_absolute_error: 0.0990 - val_loss: 0.0084 - val_mean_absolute_error: 0.0975
# Epoch 25/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0096 - mean_absolute_error: 0.1131
# Epoch 25: val_loss improved from 0.00608 to 0.00486, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0096 - mean_absolute_error: 0.1131 - val_loss: 0.0049 - val_mean_absolute_error: 0.0797
# Epoch 26/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0072 - mean_absolute_error: 0.0939
# Epoch 26: val_loss improved from 0.00486 to 0.00475, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0072 - mean_absolute_error: 0.0939 - val_loss: 0.0047 - val_mean_absolute_error: 0.0826
# Epoch 27/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0067 - mean_absolute_error: 0.0919
# Epoch 27: val_loss improved from 0.00475 to 0.00394, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0067 - mean_absolute_error: 0.0919 - val_loss: 0.0039 - val_mean_absolute_error: 0.0707
# Epoch 28/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0069 - mean_absolute_error: 0.0945
# Epoch 28: val_loss improved from 0.00394 to 0.00367, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0069 - mean_absolute_error: 0.0945 - val_loss: 0.0037 - val_mean_absolute_error: 0.0627
# Epoch 29/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0066 - mean_absolute_error: 0.0908
# Epoch 29: val_loss improved from 0.00367 to 0.00314, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0066 - mean_absolute_error: 0.0908 - val_loss: 0.0031 - val_mean_absolute_error: 0.0648
# Epoch 30/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0058 - mean_absolute_error: 0.0849
# Epoch 30: val_loss improved from 0.00314 to 0.00271, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0058 - mean_absolute_error: 0.0849 - val_loss: 0.0027 - val_mean_absolute_error: 0.0587
# Epoch 31/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0048 - mean_absolute_error: 0.0786
# Epoch 31: val_loss improved from 0.00271 to 0.00259, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0048 - mean_absolute_error: 0.0786 - val_loss: 0.0026 - val_mean_absolute_error: 0.0523
# Epoch 32/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0056 - mean_absolute_error: 0.0856
# Epoch 32: val_loss did not improve from 0.00259
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0056 - mean_absolute_error: 0.0856 - val_loss: 0.0028 - val_mean_absolute_error: 0.0628
# Epoch 33/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0053 - mean_absolute_error: 0.0826
# Epoch 33: val_loss improved from 0.00259 to 0.00233, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0053 - mean_absolute_error: 0.0826 - val_loss: 0.0023 - val_mean_absolute_error: 0.0546
# Epoch 34/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0054 - mean_absolute_error: 0.0831
# Epoch 34: val_loss improved from 0.00233 to 0.00231, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0054 - mean_absolute_error: 0.0831 - val_loss: 0.0023 - val_mean_absolute_error: 0.0490
# Epoch 35/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0050 - mean_absolute_error: 0.0781
# Epoch 35: val_loss did not improve from 0.00231
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0050 - mean_absolute_error: 0.0781 - val_loss: 0.0024 - val_mean_absolute_error: 0.0498
# Epoch 36/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0048 - mean_absolute_error: 0.0777
# Epoch 36: val_loss improved from 0.00231 to 0.00217, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0048 - mean_absolute_error: 0.0777 - val_loss: 0.0022 - val_mean_absolute_error: 0.0524
# Epoch 37/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0048 - mean_absolute_error: 0.0802
# Epoch 37: val_loss did not improve from 0.00217
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0048 - mean_absolute_error: 0.0802 - val_loss: 0.0033 - val_mean_absolute_error: 0.0703
# Epoch 38/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0053 - mean_absolute_error: 0.0820
# Epoch 38: val_loss improved from 0.00217 to 0.00207, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0053 - mean_absolute_error: 0.0820 - val_loss: 0.0021 - val_mean_absolute_error: 0.0472
# Epoch 39/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0050 - mean_absolute_error: 0.0786
# Epoch 39: val_loss did not improve from 0.00207
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0050 - mean_absolute_error: 0.0786 - val_loss: 0.0029 - val_mean_absolute_error: 0.0546
# Epoch 40/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0050 - mean_absolute_error: 0.0785
# Epoch 40: val_loss did not improve from 0.00207
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0050 - mean_absolute_error: 0.0785 - val_loss: 0.0031 - val_mean_absolute_error: 0.0675
# Epoch 41/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0049 - mean_absolute_error: 0.0784
# Epoch 41: val_loss improved from 0.00207 to 0.00207, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0049 - mean_absolute_error: 0.0784 - val_loss: 0.0021 - val_mean_absolute_error: 0.0471
# Epoch 42/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0043 - mean_absolute_error: 0.0776
# Epoch 42: val_loss improved from 0.00207 to 0.00193, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0043 - mean_absolute_error: 0.0776 - val_loss: 0.0019 - val_mean_absolute_error: 0.0463
# Epoch 43/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0038 - mean_absolute_error: 0.0681
# Epoch 43: val_loss did not improve from 0.00193
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0038 - mean_absolute_error: 0.0681 - val_loss: 0.0020 - val_mean_absolute_error: 0.0517
# Epoch 44/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0035 - mean_absolute_error: 0.0668
# Epoch 44: val_loss improved from 0.00193 to 0.00184, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0035 - mean_absolute_error: 0.0668 - val_loss: 0.0018 - val_mean_absolute_error: 0.0452
# Epoch 45/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0040 - mean_absolute_error: 0.0719
# Epoch 45: val_loss did not improve from 0.00184
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0040 - mean_absolute_error: 0.0719 - val_loss: 0.0021 - val_mean_absolute_error: 0.0474
# Epoch 46/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0037 - mean_absolute_error: 0.0695
# Epoch 46: val_loss did not improve from 0.00184
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0037 - mean_absolute_error: 0.0695 - val_loss: 0.0018 - val_mean_absolute_error: 0.0435
# Epoch 47/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0042 - mean_absolute_error: 0.0709
# Epoch 47: val_loss improved from 0.00184 to 0.00183, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0042 - mean_absolute_error: 0.0709 - val_loss: 0.0018 - val_mean_absolute_error: 0.0486
# Epoch 48/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0037 - mean_absolute_error: 0.0660
# Epoch 48: val_loss did not improve from 0.00183
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0037 - mean_absolute_error: 0.0660 - val_loss: 0.0018 - val_mean_absolute_error: 0.0477
# Epoch 49/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0040 - mean_absolute_error: 0.0721
# Epoch 49: val_loss did not improve from 0.00183
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0040 - mean_absolute_error: 0.0721 - val_loss: 0.0020 - val_mean_absolute_error: 0.0444
# Epoch 50/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0043 - mean_absolute_error: 0.0740
# Epoch 50: val_loss improved from 0.00183 to 0.00167, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0043 - mean_absolute_error: 0.0740 - val_loss: 0.0017 - val_mean_absolute_error: 0.0438
# Epoch 51/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0038 - mean_absolute_error: 0.0691
# Epoch 51: val_loss did not improve from 0.00167
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0038 - mean_absolute_error: 0.0691 - val_loss: 0.0040 - val_mean_absolute_error: 0.0783
# Epoch 52/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0053 - mean_absolute_error: 0.0836
# Epoch 52: val_loss did not improve from 0.00167
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0053 - mean_absolute_error: 0.0836 - val_loss: 0.0022 - val_mean_absolute_error: 0.0465
# Epoch 53/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0047 - mean_absolute_error: 0.0788
# Epoch 53: val_loss did not improve from 0.00167
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0047 - mean_absolute_error: 0.0788 - val_loss: 0.0023 - val_mean_absolute_error: 0.0479
# Epoch 54/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0048 - mean_absolute_error: 0.0775
# Epoch 54: val_loss did not improve from 0.00167
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0048 - mean_absolute_error: 0.0775 - val_loss: 0.0023 - val_mean_absolute_error: 0.0572
# Epoch 55/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0038 - mean_absolute_error: 0.0683
# Epoch 55: val_loss did not improve from 0.00167
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0038 - mean_absolute_error: 0.0683 - val_loss: 0.0022 - val_mean_absolute_error: 0.0485
# Epoch 56/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0038 - mean_absolute_error: 0.0703
# Epoch 56: val_loss did not improve from 0.00167
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0038 - mean_absolute_error: 0.0703 - val_loss: 0.0018 - val_mean_absolute_error: 0.0433
# Epoch 57/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0038 - mean_absolute_error: 0.0687
# Epoch 57: val_loss did not improve from 0.00167
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0038 - mean_absolute_error: 0.0687 - val_loss: 0.0017 - val_mean_absolute_error: 0.0453
# Epoch 58/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0038 - mean_absolute_error: 0.0689
# Epoch 58: val_loss did not improve from 0.00167
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0038 - mean_absolute_error: 0.0689 - val_loss: 0.0017 - val_mean_absolute_error: 0.0420
# Epoch 59/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0031 - mean_absolute_error: 0.0620
# Epoch 59: val_loss did not improve from 0.00167
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0031 - mean_absolute_error: 0.0620 - val_loss: 0.0022 - val_mean_absolute_error: 0.0554
# Epoch 60/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0037 - mean_absolute_error: 0.0686
# Epoch 60: val_loss did not improve from 0.00167
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0037 - mean_absolute_error: 0.0686 - val_loss: 0.0017 - val_mean_absolute_error: 0.0429
# Epoch 61/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0031 - mean_absolute_error: 0.0641
# Epoch 61: val_loss did not improve from 0.00167
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0031 - mean_absolute_error: 0.0641 - val_loss: 0.0018 - val_mean_absolute_error: 0.0435
# Epoch 62/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0035 - mean_absolute_error: 0.0667
# Epoch 62: val_loss did not improve from 0.00167
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0035 - mean_absolute_error: 0.0667 - val_loss: 0.0018 - val_mean_absolute_error: 0.0435
# Epoch 63/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0036 - mean_absolute_error: 0.0655
# Epoch 63: val_loss did not improve from 0.00167
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0036 - mean_absolute_error: 0.0655 - val_loss: 0.0019 - val_mean_absolute_error: 0.0503
# Epoch 64/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0032 - mean_absolute_error: 0.0630
# Epoch 64: val_loss did not improve from 0.00167
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0032 - mean_absolute_error: 0.0630 - val_loss: 0.0017 - val_mean_absolute_error: 0.0423
# Epoch 65/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0033 - mean_absolute_error: 0.0659
# Epoch 65: val_loss improved from 0.00167 to 0.00159, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0033 - mean_absolute_error: 0.0659 - val_loss: 0.0016 - val_mean_absolute_error: 0.0426
# Epoch 66/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0031 - mean_absolute_error: 0.0612
# Epoch 66: val_loss improved from 0.00159 to 0.00155, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0031 - mean_absolute_error: 0.0612 - val_loss: 0.0016 - val_mean_absolute_error: 0.0417
# Epoch 67/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0033 - mean_absolute_error: 0.0647
# Epoch 67: val_loss improved from 0.00155 to 0.00153, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0033 - mean_absolute_error: 0.0647 - val_loss: 0.0015 - val_mean_absolute_error: 0.0410
# Epoch 68/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0624
# Epoch 68: val_loss did not improve from 0.00153
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0030 - mean_absolute_error: 0.0624 - val_loss: 0.0018 - val_mean_absolute_error: 0.0435
# Epoch 69/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0033 - mean_absolute_error: 0.0653
# Epoch 69: val_loss did not improve from 0.00153
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0033 - mean_absolute_error: 0.0653 - val_loss: 0.0017 - val_mean_absolute_error: 0.0444
# Epoch 70/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0035 - mean_absolute_error: 0.0671
# Epoch 70: val_loss did not improve from 0.00153
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0035 - mean_absolute_error: 0.0671 - val_loss: 0.0018 - val_mean_absolute_error: 0.0466
# Epoch 71/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0033 - mean_absolute_error: 0.0644
# Epoch 71: val_loss did not improve from 0.00153
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0033 - mean_absolute_error: 0.0644 - val_loss: 0.0018 - val_mean_absolute_error: 0.0485
# Epoch 72/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0616
# Epoch 72: val_loss did not improve from 0.00153
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0029 - mean_absolute_error: 0.0616 - val_loss: 0.0017 - val_mean_absolute_error: 0.0426
# Epoch 73/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0032 - mean_absolute_error: 0.0639
# Epoch 73: val_loss did not improve from 0.00153
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0032 - mean_absolute_error: 0.0639 - val_loss: 0.0022 - val_mean_absolute_error: 0.0497
# Epoch 74/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0034 - mean_absolute_error: 0.0662
# Epoch 74: val_loss did not improve from 0.00153
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0034 - mean_absolute_error: 0.0662 - val_loss: 0.0017 - val_mean_absolute_error: 0.0471
# Epoch 75/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0036 - mean_absolute_error: 0.0675
# Epoch 75: val_loss did not improve from 0.00153
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0036 - mean_absolute_error: 0.0675 - val_loss: 0.0018 - val_mean_absolute_error: 0.0477
# Epoch 76/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0033 - mean_absolute_error: 0.0653
# Epoch 76: val_loss did not improve from 0.00153
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0033 - mean_absolute_error: 0.0653 - val_loss: 0.0021 - val_mean_absolute_error: 0.0467
# Epoch 77/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0620
# Epoch 77: val_loss did not improve from 0.00153
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0030 - mean_absolute_error: 0.0620 - val_loss: 0.0015 - val_mean_absolute_error: 0.0410
# Epoch 78/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0627
# Epoch 78: val_loss did not improve from 0.00153
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0030 - mean_absolute_error: 0.0627 - val_loss: 0.0016 - val_mean_absolute_error: 0.0409
# Epoch 79/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0035 - mean_absolute_error: 0.0666
# Epoch 79: val_loss improved from 0.00153 to 0.00149, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0035 - mean_absolute_error: 0.0666 - val_loss: 0.0015 - val_mean_absolute_error: 0.0401
# Epoch 80/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0618
# Epoch 80: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0030 - mean_absolute_error: 0.0618 - val_loss: 0.0016 - val_mean_absolute_error: 0.0443
# Epoch 81/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0032 - mean_absolute_error: 0.0638
# Epoch 81: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0032 - mean_absolute_error: 0.0638 - val_loss: 0.0016 - val_mean_absolute_error: 0.0443
# Epoch 82/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0032 - mean_absolute_error: 0.0648
# Epoch 82: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0032 - mean_absolute_error: 0.0648 - val_loss: 0.0015 - val_mean_absolute_error: 0.0415
# Epoch 83/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0579
# Epoch 83: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0025 - mean_absolute_error: 0.0579 - val_loss: 0.0016 - val_mean_absolute_error: 0.0451
# Epoch 84/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0032 - mean_absolute_error: 0.0645
# Epoch 84: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0032 - mean_absolute_error: 0.0645 - val_loss: 0.0017 - val_mean_absolute_error: 0.0477
# Epoch 85/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0031 - mean_absolute_error: 0.0606
# Epoch 85: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0031 - mean_absolute_error: 0.0606 - val_loss: 0.0019 - val_mean_absolute_error: 0.0452
# Epoch 86/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0606
# Epoch 86: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0029 - mean_absolute_error: 0.0606 - val_loss: 0.0015 - val_mean_absolute_error: 0.0409
# Epoch 87/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0566
# Epoch 87: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0026 - mean_absolute_error: 0.0566 - val_loss: 0.0019 - val_mean_absolute_error: 0.0501
# Epoch 88/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0028 - mean_absolute_error: 0.0602
# Epoch 88: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0028 - mean_absolute_error: 0.0602 - val_loss: 0.0015 - val_mean_absolute_error: 0.0415
# Epoch 89/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0028 - mean_absolute_error: 0.0606
# Epoch 89: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0028 - mean_absolute_error: 0.0606 - val_loss: 0.0017 - val_mean_absolute_error: 0.0445
# Epoch 90/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0623
# Epoch 90: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0030 - mean_absolute_error: 0.0623 - val_loss: 0.0017 - val_mean_absolute_error: 0.0470
# Epoch 91/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0605
# Epoch 91: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0030 - mean_absolute_error: 0.0605 - val_loss: 0.0017 - val_mean_absolute_error: 0.0457
# Epoch 92/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0561
# Epoch 92: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0027 - mean_absolute_error: 0.0561 - val_loss: 0.0015 - val_mean_absolute_error: 0.0407
# Epoch 93/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0028 - mean_absolute_error: 0.0611
# Epoch 93: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0028 - mean_absolute_error: 0.0611 - val_loss: 0.0016 - val_mean_absolute_error: 0.0415
# Epoch 94/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0034 - mean_absolute_error: 0.0656
# Epoch 94: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0034 - mean_absolute_error: 0.0656 - val_loss: 0.0016 - val_mean_absolute_error: 0.0419
# Epoch 95/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0031 - mean_absolute_error: 0.0624
# Epoch 95: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0031 - mean_absolute_error: 0.0624 - val_loss: 0.0015 - val_mean_absolute_error: 0.0420
# Epoch 96/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0564
# Epoch 96: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0025 - mean_absolute_error: 0.0564 - val_loss: 0.0016 - val_mean_absolute_error: 0.0443
# Epoch 97/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0028 - mean_absolute_error: 0.0616
# Epoch 97: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0028 - mean_absolute_error: 0.0616 - val_loss: 0.0017 - val_mean_absolute_error: 0.0461
# Epoch 98/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0598
# Epoch 98: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0030 - mean_absolute_error: 0.0598 - val_loss: 0.0016 - val_mean_absolute_error: 0.0438
# Epoch 99/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0035 - mean_absolute_error: 0.0681
# Epoch 99: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0035 - mean_absolute_error: 0.0681 - val_loss: 0.0017 - val_mean_absolute_error: 0.0430
# Epoch 100/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0028 - mean_absolute_error: 0.0608
# Epoch 100: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0028 - mean_absolute_error: 0.0608 - val_loss: 0.0021 - val_mean_absolute_error: 0.0482
# Epoch 101/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0036 - mean_absolute_error: 0.0667
# Epoch 101: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0036 - mean_absolute_error: 0.0667 - val_loss: 0.0018 - val_mean_absolute_error: 0.0478
# Epoch 102/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0031 - mean_absolute_error: 0.0600
# Epoch 102: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0031 - mean_absolute_error: 0.0600 - val_loss: 0.0019 - val_mean_absolute_error: 0.0492
# Epoch 103/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0609
# Epoch 103: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0030 - mean_absolute_error: 0.0609 - val_loss: 0.0018 - val_mean_absolute_error: 0.0444
# Epoch 104/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0028 - mean_absolute_error: 0.0606
# Epoch 104: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0028 - mean_absolute_error: 0.0606 - val_loss: 0.0019 - val_mean_absolute_error: 0.0511
# Epoch 105/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0028 - mean_absolute_error: 0.0609
# Epoch 105: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0028 - mean_absolute_error: 0.0609 - val_loss: 0.0015 - val_mean_absolute_error: 0.0424
# Epoch 106/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0611
# Epoch 106: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0029 - mean_absolute_error: 0.0611 - val_loss: 0.0016 - val_mean_absolute_error: 0.0415
# Epoch 107/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0031 - mean_absolute_error: 0.0628
# Epoch 107: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0031 - mean_absolute_error: 0.0628 - val_loss: 0.0015 - val_mean_absolute_error: 0.0415
# Epoch 108/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0620
# Epoch 108: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0030 - mean_absolute_error: 0.0620 - val_loss: 0.0015 - val_mean_absolute_error: 0.0417
# Epoch 109/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0589
# Epoch 109: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0027 - mean_absolute_error: 0.0589 - val_loss: 0.0015 - val_mean_absolute_error: 0.0425
# Epoch 110/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0023 - mean_absolute_error: 0.0546
# Epoch 110: val_loss did not improve from 0.00149
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0023 - mean_absolute_error: 0.0546 - val_loss: 0.0015 - val_mean_absolute_error: 0.0414
# Epoch 111/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0598
# Epoch 111: val_loss improved from 0.00149 to 0.00148, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0029 - mean_absolute_error: 0.0598 - val_loss: 0.0015 - val_mean_absolute_error: 0.0416
# Epoch 112/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0574
# Epoch 112: val_loss did not improve from 0.00148
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0025 - mean_absolute_error: 0.0574 - val_loss: 0.0015 - val_mean_absolute_error: 0.0430
# Epoch 113/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0567
# Epoch 113: val_loss improved from 0.00148 to 0.00146, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0025 - mean_absolute_error: 0.0567 - val_loss: 0.0015 - val_mean_absolute_error: 0.0409
# Epoch 114/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0564
# Epoch 114: val_loss improved from 0.00146 to 0.00144, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0027 - mean_absolute_error: 0.0564 - val_loss: 0.0014 - val_mean_absolute_error: 0.0403
# Epoch 115/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0023 - mean_absolute_error: 0.0551
# Epoch 115: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0023 - mean_absolute_error: 0.0551 - val_loss: 0.0017 - val_mean_absolute_error: 0.0481
# Epoch 116/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0587
# Epoch 116: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0027 - mean_absolute_error: 0.0587 - val_loss: 0.0015 - val_mean_absolute_error: 0.0434
# Epoch 117/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0023 - mean_absolute_error: 0.0564
# Epoch 117: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0023 - mean_absolute_error: 0.0564 - val_loss: 0.0020 - val_mean_absolute_error: 0.0467
# Epoch 118/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0576
# Epoch 118: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0026 - mean_absolute_error: 0.0576 - val_loss: 0.0015 - val_mean_absolute_error: 0.0421
# Epoch 119/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0591
# Epoch 119: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0029 - mean_absolute_error: 0.0591 - val_loss: 0.0033 - val_mean_absolute_error: 0.0715
# Epoch 120/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0036 - mean_absolute_error: 0.0681
# Epoch 120: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0036 - mean_absolute_error: 0.0681 - val_loss: 0.0018 - val_mean_absolute_error: 0.0458
# Epoch 121/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0562
# Epoch 121: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0026 - mean_absolute_error: 0.0562 - val_loss: 0.0015 - val_mean_absolute_error: 0.0408
# Epoch 122/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0565
# Epoch 122: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0026 - mean_absolute_error: 0.0565 - val_loss: 0.0016 - val_mean_absolute_error: 0.0424
# Epoch 123/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0580
# Epoch 123: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0026 - mean_absolute_error: 0.0580 - val_loss: 0.0017 - val_mean_absolute_error: 0.0435
# Epoch 124/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0614
# Epoch 124: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0029 - mean_absolute_error: 0.0614 - val_loss: 0.0015 - val_mean_absolute_error: 0.0426
# Epoch 125/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0028 - mean_absolute_error: 0.0610
# Epoch 125: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0028 - mean_absolute_error: 0.0610 - val_loss: 0.0018 - val_mean_absolute_error: 0.0481
# Epoch 126/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0032 - mean_absolute_error: 0.0639
# Epoch 126: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0032 - mean_absolute_error: 0.0639 - val_loss: 0.0018 - val_mean_absolute_error: 0.0454
# Epoch 127/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0580
# Epoch 127: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0026 - mean_absolute_error: 0.0580 - val_loss: 0.0015 - val_mean_absolute_error: 0.0403
# Epoch 128/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0559
# Epoch 128: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0024 - mean_absolute_error: 0.0559 - val_loss: 0.0017 - val_mean_absolute_error: 0.0464
# Epoch 129/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0023 - mean_absolute_error: 0.0537
# Epoch 129: val_loss did not improve from 0.00144
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0023 - mean_absolute_error: 0.0537 - val_loss: 0.0015 - val_mean_absolute_error: 0.0406
# Epoch 130/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0608
# Epoch 130: val_loss improved from 0.00144 to 0.00142, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0030 - mean_absolute_error: 0.0608 - val_loss: 0.0014 - val_mean_absolute_error: 0.0404
# Epoch 131/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0590
# Epoch 131: val_loss did not improve from 0.00142
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0027 - mean_absolute_error: 0.0590 - val_loss: 0.0016 - val_mean_absolute_error: 0.0439
# Epoch 132/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0569
# Epoch 132: val_loss did not improve from 0.00142
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0026 - mean_absolute_error: 0.0569 - val_loss: 0.0015 - val_mean_absolute_error: 0.0425
# Epoch 133/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0023 - mean_absolute_error: 0.0529
# Epoch 133: val_loss did not improve from 0.00142
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0023 - mean_absolute_error: 0.0529 - val_loss: 0.0016 - val_mean_absolute_error: 0.0430
# Epoch 134/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0523
# Epoch 134: val_loss did not improve from 0.00142
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0022 - mean_absolute_error: 0.0523 - val_loss: 0.0015 - val_mean_absolute_error: 0.0432
# Epoch 135/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0532
# Epoch 135: val_loss did not improve from 0.00142
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0024 - mean_absolute_error: 0.0532 - val_loss: 0.0018 - val_mean_absolute_error: 0.0489
# Epoch 136/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0578
# Epoch 136: val_loss did not improve from 0.00142
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0025 - mean_absolute_error: 0.0578 - val_loss: 0.0017 - val_mean_absolute_error: 0.0428
# Epoch 137/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0578
# Epoch 137: val_loss did not improve from 0.00142
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0027 - mean_absolute_error: 0.0578 - val_loss: 0.0019 - val_mean_absolute_error: 0.0462
# Epoch 138/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0031 - mean_absolute_error: 0.0644
# Epoch 138: val_loss did not improve from 0.00142
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0031 - mean_absolute_error: 0.0644 - val_loss: 0.0020 - val_mean_absolute_error: 0.0523
# Epoch 139/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0584
# Epoch 139: val_loss did not improve from 0.00142
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0026 - mean_absolute_error: 0.0584 - val_loss: 0.0015 - val_mean_absolute_error: 0.0420
# Epoch 140/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0563
# Epoch 140: val_loss did not improve from 0.00142
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0024 - mean_absolute_error: 0.0563 - val_loss: 0.0019 - val_mean_absolute_error: 0.0473
# Epoch 141/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0564
# Epoch 141: val_loss did not improve from 0.00142
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0024 - mean_absolute_error: 0.0564 - val_loss: 0.0015 - val_mean_absolute_error: 0.0410
# Epoch 142/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0558
# Epoch 142: val_loss did not improve from 0.00142
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0024 - mean_absolute_error: 0.0558 - val_loss: 0.0014 - val_mean_absolute_error: 0.0408
# Epoch 143/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0520
# Epoch 143: val_loss did not improve from 0.00142
# ...
# Epoch 152: val_loss did not improve from 0.00142
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0025 - mean_absolute_error: 0.0563 - val_loss: 0.0016 - val_mean_absolute_error: 0.0429
# Epoch 153/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0564
# Epoch 153: val_loss improved from 0.00142 to 0.00142, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0024 - mean_absolute_error: 0.0564 - val_loss: 0.0014 - val_mean_absolute_error: 0.0400
# Epoch 154/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0542
# Epoch 154: val_loss improved from 0.00142 to 0.00138, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0024 - mean_absolute_error: 0.0542 - val_loss: 0.0014 - val_mean_absolute_error: 0.0402
# Epoch 155/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0592
# Epoch 155: val_loss did not improve from 0.00138
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0027 - mean_absolute_error: 0.0592 - val_loss: 0.0023 - val_mean_absolute_error: 0.0584
# Epoch 156/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0591
# Epoch 156: val_loss did not improve from 0.00138
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0027 - mean_absolute_error: 0.0591 - val_loss: 0.0015 - val_mean_absolute_error: 0.0417
# Epoch 157/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0031 - mean_absolute_error: 0.0629
# Epoch 157: val_loss did not improve from 0.00138
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0031 - mean_absolute_error: 0.0629 - val_loss: 0.0022 - val_mean_absolute_error: 0.0515
# Epoch 158/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0567
# Epoch 158: val_loss did not improve from 0.00138
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0026 - mean_absolute_error: 0.0567 - val_loss: 0.0017 - val_mean_absolute_error: 0.0467
# Epoch 159/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0567
# Epoch 159: val_loss did not improve from 0.00138
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0025 - mean_absolute_error: 0.0567 - val_loss: 0.0017 - val_mean_absolute_error: 0.0474
# Epoch 160/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0573
# Epoch 160: val_loss did not improve from 0.00138
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0025 - mean_absolute_error: 0.0573 - val_loss: 0.0021 - val_mean_absolute_error: 0.0511
# Epoch 161/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0540
# Epoch 161: val_loss improved from 0.00138 to 0.00136, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0024 - mean_absolute_error: 0.0540 - val_loss: 0.0014 - val_mean_absolute_error: 0.0398
# Epoch 162/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0023 - mean_absolute_error: 0.0549
# Epoch 162: val_loss did not improve from 0.00136
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0023 - mean_absolute_error: 0.0549 - val_loss: 0.0014 - val_mean_absolute_error: 0.0400
# Epoch 163/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0023 - mean_absolute_error: 0.0537
# Epoch 163: val_loss did not improve from 0.00136
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0023 - mean_absolute_error: 0.0537 - val_loss: 0.0014 - val_mean_absolute_error: 0.0403
# Epoch 164/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0547
# Epoch 164: val_loss did not improve from 0.00136
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0022 - mean_absolute_error: 0.0547 - val_loss: 0.0014 - val_mean_absolute_error: 0.0419
# Epoch 165/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0021 - mean_absolute_error: 0.0517
# Epoch 165: val_loss did not improve from 0.00136
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0021 - mean_absolute_error: 0.0517 - val_loss: 0.0016 - val_mean_absolute_error: 0.0427
# Epoch 166/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0020 - mean_absolute_error: 0.0499
# Epoch 166: val_loss did not improve from 0.00136
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0020 - mean_absolute_error: 0.0499 - val_loss: 0.0016 - val_mean_absolute_error: 0.0441
# Epoch 167/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0020 - mean_absolute_error: 0.0509
# Epoch 167: val_loss did not improve from 0.00136
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0020 - mean_absolute_error: 0.0509 - val_loss: 0.0016 - val_mean_absolute_error: 0.0440
# Epoch 168/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0539
# Epoch 168: val_loss did not improve from 0.00136
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0022 - mean_absolute_error: 0.0539 - val_loss: 0.0015 - val_mean_absolute_error: 0.0419
# Epoch 169/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0023 - mean_absolute_error: 0.0533
# Epoch 169: val_loss did not improve from 0.00136
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0023 - mean_absolute_error: 0.0533 - val_loss: 0.0014 - val_mean_absolute_error: 0.0401
# Epoch 170/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0584
# Epoch 170: val_loss did not improve from 0.00136
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0026 - mean_absolute_error: 0.0584 - val_loss: 0.0014 - val_mean_absolute_error: 0.0413
# Epoch 171/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0023 - mean_absolute_error: 0.0538
# Epoch 171: val_loss improved from 0.00136 to 0.00132, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0023 - mean_absolute_error: 0.0538 - val_loss: 0.0013 - val_mean_absolute_error: 0.0400
# Epoch 172/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0028 - mean_absolute_error: 0.0606
# Epoch 172: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0028 - mean_absolute_error: 0.0606 - val_loss: 0.0019 - val_mean_absolute_error: 0.0463
# Epoch 173/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0535
# Epoch 173: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0024 - mean_absolute_error: 0.0535 - val_loss: 0.0017 - val_mean_absolute_error: 0.0472
# Epoch 174/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0532
# Epoch 174: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0022 - mean_absolute_error: 0.0532 - val_loss: 0.0015 - val_mean_absolute_error: 0.0420
# Epoch 175/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0023 - mean_absolute_error: 0.0566
# Epoch 175: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0023 - mean_absolute_error: 0.0566 - val_loss: 0.0017 - val_mean_absolute_error: 0.0464
# Epoch 176/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0571
# Epoch 176: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0024 - mean_absolute_error: 0.0571 - val_loss: 0.0015 - val_mean_absolute_error: 0.0428
# Epoch 177/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0599
# Epoch 177: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0027 - mean_absolute_error: 0.0599 - val_loss: 0.0021 - val_mean_absolute_error: 0.0507
# Epoch 178/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0629
# Epoch 178: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0029 - mean_absolute_error: 0.0629 - val_loss: 0.0016 - val_mean_absolute_error: 0.0433
# Epoch 179/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0552
# Epoch 179: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0025 - mean_absolute_error: 0.0552 - val_loss: 0.0023 - val_mean_absolute_error: 0.0567
# Epoch 180/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0030 - mean_absolute_error: 0.0621
# Epoch 180: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0030 - mean_absolute_error: 0.0621 - val_loss: 0.0015 - val_mean_absolute_error: 0.0419
# Epoch 181/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0028 - mean_absolute_error: 0.0584
# Epoch 181: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0028 - mean_absolute_error: 0.0584 - val_loss: 0.0015 - val_mean_absolute_error: 0.0430
# Epoch 182/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0540
# Epoch 182: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0022 - mean_absolute_error: 0.0540 - val_loss: 0.0018 - val_mean_absolute_error: 0.0481
# Epoch 183/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0522
# Epoch 183: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0022 - mean_absolute_error: 0.0522 - val_loss: 0.0017 - val_mean_absolute_error: 0.0458
# Epoch 184/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0555
# Epoch 184: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0024 - mean_absolute_error: 0.0555 - val_loss: 0.0014 - val_mean_absolute_error: 0.0408
# Epoch 185/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0020 - mean_absolute_error: 0.0502
# Epoch 185: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0020 - mean_absolute_error: 0.0502 - val_loss: 0.0015 - val_mean_absolute_error: 0.0429
# Epoch 186/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0020 - mean_absolute_error: 0.0498
# Epoch 186: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0020 - mean_absolute_error: 0.0498 - val_loss: 0.0013 - val_mean_absolute_error: 0.0398
# Epoch 187/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0020 - mean_absolute_error: 0.0495
# Epoch 187: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0020 - mean_absolute_error: 0.0495 - val_loss: 0.0013 - val_mean_absolute_error: 0.0395
# Epoch 188/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0026 - mean_absolute_error: 0.0561
# Epoch 188: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0026 - mean_absolute_error: 0.0561 - val_loss: 0.0015 - val_mean_absolute_error: 0.0417
# Epoch 189/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0021 - mean_absolute_error: 0.0513
# Epoch 189: val_loss did not improve from 0.00132
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0021 - mean_absolute_error: 0.0513 - val_loss: 0.0016 - val_mean_absolute_error: 0.0441
# Epoch 190/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0575
# Epoch 190: val_loss improved from 0.00132 to 0.00131, saving model to results\2023-01-07_SPY-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0025 - mean_absolute_error: 0.0575 - val_loss: 0.0013 - val_mean_absolute_error: 0.0392
# Epoch 191/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0517
# Epoch 191: val_loss did not improve from 0.00131
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0022 - mean_absolute_error: 0.0517 - val_loss: 0.0015 - val_mean_absolute_error: 0.0419
# Epoch 192/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0521
# Epoch 192: val_loss did not improve from 0.00131
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0022 - mean_absolute_error: 0.0521 - val_loss: 0.0014 - val_mean_absolute_error: 0.0413
# Epoch 193/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0021 - mean_absolute_error: 0.0500
# Epoch 193: val_loss did not improve from 0.00131
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0021 - mean_absolute_error: 0.0500 - val_loss: 0.0013 - val_mean_absolute_error: 0.0397
# Epoch 194/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0023 - mean_absolute_error: 0.0536
# Epoch 194: val_loss did not improve from 0.00131
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0023 - mean_absolute_error: 0.0536 - val_loss: 0.0018 - val_mean_absolute_error: 0.0496
# Epoch 195/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0559
# Epoch 195: val_loss did not improve from 0.00131
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0025 - mean_absolute_error: 0.0559 - val_loss: 0.0019 - val_mean_absolute_error: 0.0506
# Epoch 196/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0025 - mean_absolute_error: 0.0566
# Epoch 196: val_loss did not improve from 0.00131
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0025 - mean_absolute_error: 0.0566 - val_loss: 0.0026 - val_mean_absolute_error: 0.0560
# Epoch 197/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0027 - mean_absolute_error: 0.0579
# Epoch 197: val_loss did not improve from 0.00131
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0027 - mean_absolute_error: 0.0579 - val_loss: 0.0013 - val_mean_absolute_error: 0.0404
# Epoch 198/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0547
# Epoch 198: val_loss did not improve from 0.00131
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0024 - mean_absolute_error: 0.0547 - val_loss: 0.0022 - val_mean_absolute_error: 0.0569
# Epoch 199/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0028 - mean_absolute_error: 0.0604
# Epoch 199: val_loss did not improve from 0.00131
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0028 - mean_absolute_error: 0.0604 - val_loss: 0.0017 - val_mean_absolute_error: 0.0458
# Epoch 200/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0029 - mean_absolute_error: 0.0598
# Epoch 200: val_loss did not improve from 0.00131
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0029 - mean_absolute_error: 0.0598 - val_loss: 0.0015 - val_mean_absolute_error: 0.0417
# [*********************100%***********************]  1 of 1 completed
# removing last day for testing by damian
#                   Open        High         Low       Close     Volume
# Date
# 2022-12-07  391.143858  393.831529  390.178291  391.362854   65927900
# 2022-12-08  393.333824  395.543648  391.472347  394.428772   60737900
# 2022-12-09  393.134716  395.802458  391.352889  391.482300   81367500
# 2022-12-12  392.308501  397.126404  391.611719  397.126404   75405800
# 2022-12-13  408.344888  408.613643  397.245861  400.132599  123782500
# Mean Absolute Error: 360.12606327875665

# %%
def predict(model, data):
    last_sequence = data["last_sequence"][-N_STEPS:]
    column_scaler = data["column_scaler"]
    # Swap dimensions
    last_sequence = last_sequence.reshape((last_sequence.shape[1], last_sequence.shape[0]))
    last_sequence = np.expand_dims(last_sequence, axis=0)
    # get the prediction (scaled from 0 to 1)
    prediction = model.predict(last_sequence)
    # get the price (by inverting the scaling)
    predicted_price = column_scaler["Close"].inverse_transform(prediction)[0][0]
    return predicted_price

# predict the future price
future_price = predict(model, data)
print(f"Future price after {LOOKUP_STEP} days is {future_price:.2f}$")
# Out:
# 1/1 [==============================] - 1s 878ms/step
# Future price after 1 days is 398.30$

# %%
def plot_graph(model, data):
    y_test = data["y_test"]
    X_test = data["X_test"]
    y_pred = model.predict(X_test)
    y_test = np.squeeze(data["column_scaler"]["Close"].inverse_transform(np.expand_dims(y_test, axis=0)))
    y_pred = np.squeeze(data["column_scaler"]["Close"].inverse_transform(y_pred))
    # currently last 200 days
    plt.plot(y_test[-200:], c='b')
    plt.plot(y_pred[-200:], c='r')
    plt.xlabel("Days")
    plt.ylabel("Price")
    plt.legend(["Actual Price", "Predicted Price"])
    plt.show()

plot_graph(model, data)
# Out:
# 4/4 [==============================] - 0s 15ms/step

# %%
def accuracy(model, data):
    y_test = data["y_test"]
    X_test = data["X_test"]
    y_pred = model.predict(X_test)
    y_test = np.squeeze(data["column_scaler"]["Close"].inverse_transform(np.expand_dims(y_test, axis=0)))
    y_pred = np.squeeze(data["column_scaler"]["Close"].inverse_transform(y_pred))
    y_pred = list(map(lambda current, future: int(float(future) > float(current)), y_test[:-LOOKUP_STEP], y_pred[LOOKUP_STEP:]))
    y_test = list(map(lambda current, future: int(float(future) > float(current)), y_test[:-LOOKUP_STEP], y_test[LOOKUP_STEP:]))
    return accuracy_score(y_test, y_pred)

print(str(LOOKUP_STEP) + ":", "Accuracy Score:", accuracy(model, data))
# Out:
# 4/4 [==============================] - 0s 15ms/step
# 1: Accuracy Score: 0.488

# %%
data["df"]
# Out:
#                  Open       High        Low      Close    Volume
# Date
# 2018-01-08  25.608324  25.653442  25.509068  25.599302  44252100
# 2018-01-09  25.707585  25.933169  25.662469  25.797819  51418700
# 2018-01-10  25.879025  26.122657  25.833908  26.014376  64670900
# 2018-01-11  26.122662  26.167778  25.996333  26.140707  42361700
# 2018-01-12  26.294102  26.393360  26.131681  26.375313  44537500
# ...               ...        ...        ...        ...       ...
# 2022-12-30  34.040001  34.270000  33.919998  34.200001  24725300
# 2023-01-03  34.450001  34.689999  34.070000  34.320000  37396500
# 2023-01-04  34.669998  35.119999  34.570000  34.869999  44669300
# 2023-01-05  34.750000  34.750000  34.369999  34.610001  45585700
# 2023-01-06  34.840000  35.490002  34.599998  35.380001  41205100
#
# [1259 rows x 5 columns]

# %%
data["y_test"].shape
# Out:
# (238,)

# %%
data["X_test"].shape
# Out:
# (238, 5, 70)

# %%
data["X_train"].shape
# Out:
# (951, 5, 70)

# %%
data["y_train"].shape
# Out:
# (951,)

# %%
data["df"].shape
# Out:
# (1259, 5)

# %%
#model_path = os.path.join("results", model_name) + ".h5"
#model.load_weights(model_path)
model_path  #'results\\2023-01-07_XLF-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5'
# Out:
# 'results\\2023-01-07_XLF-huber_loss-adam-LSTM-seq-70-step-1-layers-3-units-256.h5'

# %%
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)

# %%
model.load_weights(model_path)

# %%
last_sequence = data["last_sequence"][-70:]
last_sequence.shape  # 5 features
# Out:
# (70, 5)

# %%
# Out:
# (1, 5, 70)

# %%
# Out:
# (5, 70)

# %%
def load_data_1(ticker, period, interval, n_steps=50, scale=True, shuffle=True, lookup_step=1, test_size=.2,
              feature_columns=['Close', 'Volume', 'Open', 'High', 'Low']):
    '''
    :param ticker: Ticker you want to load, dtype: str
    :param period: Time period you want data from, dtype: str(options in program)
    :param interval: Interval for data, dtype:str
    :param n_steps: Past sequence len used to predict, default = 50, dtype: int
    :param scale: Whether to scale data b/w 0 and 1, default = True, dtype: Bool
    :param shuffle: Whether to shuffle data, default = True, dtyper: Bool
    :param lookup_step: Future lookup step to predict, default = 1(next day), dtype:int
    :param test_size: ratio for test data, default is .2 (20% test data), dtype: float
    :param feature_columns: list of features fed into the model, default is OHLCV, dtype: list
    :return:
    '''
    df = yf.download(tickers=ticker, period=period, interval=interval,
                     group_by='ticker',
                     # adjust all OHLC automatically
                     auto_adjust=True, prepost=True, threads=True, proxy=None)
    
    return(df)

# %%
data1 = load_data_1('SPY', PERIOD, INTERVAL, N_STEPS, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE, feature_columns=FEATURE_COLUMNS)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data1
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2021-01-07  365.227382  368.917517  365.042872  368.140656   68766800
# 2021-01-08  369.587607  370.461583  366.198508  370.238251   71677200
# 2021-01-11  366.926841  369.577901  366.800594  367.742554   51034700
# 2021-01-12  367.936746  368.878676  365.479857  367.820190   52547700
# 2021-01-13  367.742524  369.849775  366.926811  368.810730   45303600
# ...                ...         ...         ...         ...        ...
# 2022-12-30  380.640015  382.579987  378.429993  382.429993   83975100
# 2023-01-03  384.369995  386.429993  377.829987  380.820007   74850700
# 2023-01-04  383.179993  385.880005  380.000000  383.760010   85934100
# 2023-01-05  381.720001  381.839996  378.760010  379.380005   76970500
# 2023-01-06  382.609985  389.250000  379.410004  388.079987  104041300
#
# [504 rows x 5 columns]

# %%
data1.iloc[:-16 , :]
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2021-01-07  365.227382  368.917517  365.042872  368.140656   68766800
# 2021-01-08  369.587607  370.461583  366.198508  370.238251   71677200
# 2021-01-11  366.926841  369.577901  366.800594  367.742554   51034700
# 2021-01-12  367.936746  368.878676  365.479857  367.820190   52547700
# 2021-01-13  367.742524  369.849775  366.926811  368.810730   45303600
# ...                ...         ...         ...         ...        ...
# 2022-12-07  391.143858  393.831529  390.178291  391.362854   65927900
# 2022-12-08  393.333824  395.543648  391.472347  394.428772   60737900
# 2022-12-09  393.134716  395.802458  391.352889  391.482300   81367500
# 2022-12-12  392.308501  397.126404  391.611719  397.126404   75405800
# 2022-12-13  408.344888  408.613643  397.245861  400.132599  123782500
#
# [488 rows x 5 columns]

# %%
data1.iloc[:-17 , :]
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2021-01-07  365.227382  368.917517  365.042872  368.140656  68766800
# 2021-01-08  369.587607  370.461583  366.198508  370.238251  71677200
# 2021-01-11  366.926841  369.577901  366.800594  367.742554  51034700
# 2021-01-12  367.936746  368.878676  365.479857  367.820190  52547700
# 2021-01-13  367.742524  369.849775  366.926811  368.810730  45303600
# ...                ...         ...         ...         ...       ...
# 2022-12-06  397.594260  398.161631  389.849824  392.029785  77972200
# 2022-12-07  391.143858  393.831529  390.178291  391.362854  65927900
# 2022-12-08  393.333824  395.543648  391.472347  394.428772  60737900
# 2022-12-09  393.134716  395.802458  391.352889  391.482300  81367500
# 2022-12-12  392.308501  397.126404  391.611719  397.126404  75405800
#
# [487 rows x 5 columns]
